# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, CSVLogger

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_excel('/content/drive/MyDrive/IIT-G/data.xlsx')

# %%
data
# Out:
#    mname  mthickness (nm)  cellarea (µm2) topelectrode bottomelectrode  \
# 0   H-BN                6           0.053           Au               W
# 1   MoS2                1         100.000           Mo              Sn
# 2  MoSe2                1         100.000           Mo              Pt
# 3  PdSe2                3           1.000           Ti              Au
# 4  PdSe2                5           1.000           Ti              Au
# 5  PdSe2                7           1.000           Ti              Au
#
#   extrastack   roff_rv        ron_rv     vs    vr
# 0         Ti  0.000007  8.804207e-09  2.000 -1.68
# 1        NaN  0.005373  3.050072e-08  1.750 -1.00
# 2         Sn  0.000663  3.682850e-08  0.750 -0.75
# 3        NaN  0.000256  5.926848e-06  0.877 -1.50
# 4        NaN  0.000407  2.387368e-05  0.580 -1.50
# 5        NaN  0.000647  1.113548e-04  0.660 -1.50

# %%
data = data.fillna(0) # NAN = 0

# %%
data = data.replace('Au', 1)
data = data.replace('W', 2)
data = data.replace('Mo', 3)
data = data.replace('Sn', 4)
data = data.replace('Pt', 5)
data = data.replace('Ti', 6)
data = data.replace('H-BN', 11)
data = data.replace('MoS2', 12)
data = data.replace('MoSe2', 13)
data = data.replace('PdSe2', 14)

# Au = 1, W = 2, Mo = 3, Sn = 4, Pt = 5, Ti = 6,
# H-BN = 11, MoS2 = 12, MoSe2 = 13,PdSe2 = 14

# %%
x = data[['mname','mthickness (nm)','cellarea (µm2)','topelectrode','bottomelectrode','extrastack']]

# %%
x
# Out:
#    mname  mthickness (nm)  cellarea (µm2)  topelectrode  bottomelectrode  \
# 0     11                6           0.053             1                2
# 1     12                1         100.000             3                4
# 2     13                1         100.000             3                5
# 3     14                3           1.000             6                1
# 4     14                5           1.000             6                1
# 5     14                7           1.000             6                1
#
#    extrastack
# 0           6
# 1           0
# 2           4
# 3           0
# 4           0
# 5           0

# %%
y = data[['roff_rv','ron_rv','vs','vr']]

# %%
y
# Out:
#     roff_rv        ron_rv     vs    vr
# 0  0.000007  8.804207e-09  2.000 -1.68
# 1  0.005373  3.050072e-08  1.750 -1.00
# 2  0.000663  3.682850e-08  0.750 -0.75
# 3  0.000256  5.926848e-06  0.877 -1.50
# 4  0.000407  2.387368e-05  0.580 -1.50
# 5  0.000647  1.113548e-04  0.660 -1.50

# %%
# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
# x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2)

# %%
# print(x_train.shape)
# print(y_train.shape)
# print(x_val.shape)
# print(y_val.shape)
# print(x_test.shape)
# print(y_test.shape)

# %%
# y_train

# %%
# print(type(x_train))
# print(type(y_train))
# print(type(x_val))
# print(type(y_val))
# print(type(x_test))
# print(type(y_test))

# %%
# x_train = x_train.to_numpy()
# y_train = y_train.to_numpy()
# x_test = x_test.to_numpy()
# y_test = y_test.to_numpy()
# x_val = x_val.to_numpy()
# y_val = y_val.to_numpy()

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(256, activation='relu', input_shape=(6,)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(4, activation='linear')
])
model.compile(optimizer='adam', loss='mean_absolute_error', metrics=['mean_absolute_error'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 256)               1792
#
#  dense_13 (Dense)            (None, 128)               32896
#
#  batch_normalization_3 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_14 (Dense)            (None, 128)               16512
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_15 (Dense)            (None, 128)               16512
#
#  dense_16 (Dense)            (None, 64)                8256
#
#  batch_normalization_4 (Bat  (None, 64)                256
#  chNormalization)
#
#  dense_17 (Dense)            (None, 64)                4160
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_18 (Dense)            (None, 64)                4160
#
#  dense_19 (Dense)            (None, 32)                2080
#
#  batch_normalization_5 (Bat  (None, 32)                128
#  chNormalization)
#
#  dense_20 (Dense)            (None, 32)                1056
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense_21 (Dense)            (None, 16)                528
#
#  dense_22 (Dense)            (None, 8)                 136
#
#  dense_23 (Dense)            (None, 4)                 36
#
# =================================================================
# Total params: 89020 (347.73 KB)
# Trainable params: 88572 (345.98 KB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________

# %%
# !pip install visualkeras
import visualkeras
from tensorflow.python.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D, ZeroPadding2D
from collections import defaultdict
from PIL import ImageFont

# %%
color_map = defaultdict(dict)
color_map[Conv2D]['fill'] = 'orange'
color_map[ZeroPadding2D]['fill'] = 'gray'
color_map[Dropout]['fill'] = 'pink'
color_map[MaxPooling2D]['fill'] = 'red'
color_map[Dense]['fill'] = 'green'
color_map[Flatten]['fill'] = 'teal'

visualkeras.layered_view(model, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=563x63>

# %%
# callbacks = [EarlyStopping(patience=8, monitor='val_loss',mode='min',verbose=1),CSVLogger(filename='east.csv')]
history = model.fit(x,y, epochs=500, batch_size=32)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 4s 4s/step - loss: 0.8610 - mean_absolute_error: 0.8610
# Epoch 2/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.7848 - mean_absolute_error: 0.7848
# Epoch 3/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.7430 - mean_absolute_error: 0.7430
# Epoch 4/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.8177 - mean_absolute_error: 0.8177
# Epoch 5/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.7107 - mean_absolute_error: 0.7107
# Epoch 6/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.6462 - mean_absolute_error: 0.6462
# Epoch 7/500
# 1/1 [==============================] - 0s 39ms/step - loss: 0.7107 - mean_absolute_error: 0.7107
# Epoch 8/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.7061 - mean_absolute_error: 0.7061
# Epoch 9/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.7089 - mean_absolute_error: 0.7089
# Epoch 10/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.7519 - mean_absolute_error: 0.7519
# Epoch 11/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.6383 - mean_absolute_error: 0.6383
# Epoch 12/500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6890 - mean_absolute_error: 0.6890
# Epoch 13/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6365 - mean_absolute_error: 0.6365
# Epoch 14/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.6791 - mean_absolute_error: 0.6791
# Epoch 15/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6950 - mean_absolute_error: 0.6950
# Epoch 16/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6500 - mean_absolute_error: 0.6500
# Epoch 17/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.7117 - mean_absolute_error: 0.7117
# Epoch 18/500
# 1/1 [==============================] - 0s 47ms/step - loss: 0.6230 - mean_absolute_error: 0.6230
# Epoch 19/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.6881 - mean_absolute_error: 0.6881
# Epoch 20/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.6462 - mean_absolute_error: 0.6462
# Epoch 21/500
# 1/1 [==============================] - 0s 42ms/step - loss: 0.7106 - mean_absolute_error: 0.7106
# Epoch 22/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.6471 - mean_absolute_error: 0.6471
# Epoch 23/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.6433 - mean_absolute_error: 0.6433
# Epoch 24/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6880 - mean_absolute_error: 0.6880
# Epoch 25/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.6594 - mean_absolute_error: 0.6594
# Epoch 26/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6800 - mean_absolute_error: 0.6800
# Epoch 27/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6472 - mean_absolute_error: 0.6472
# Epoch 28/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6099 - mean_absolute_error: 0.6099
# Epoch 29/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6329 - mean_absolute_error: 0.6329
# Epoch 30/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6942 - mean_absolute_error: 0.6942
# Epoch 31/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6340 - mean_absolute_error: 0.6340
# Epoch 32/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6035 - mean_absolute_error: 0.6035
# Epoch 33/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6783 - mean_absolute_error: 0.6783
# Epoch 34/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.7085 - mean_absolute_error: 0.7085
# Epoch 35/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6513 - mean_absolute_error: 0.6513
# Epoch 36/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6281 - mean_absolute_error: 0.6281
# Epoch 37/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6333 - mean_absolute_error: 0.6333
# Epoch 38/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6332 - mean_absolute_error: 0.6332
# Epoch 39/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6499 - mean_absolute_error: 0.6499
# Epoch 40/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5923 - mean_absolute_error: 0.5923
# Epoch 41/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6015 - mean_absolute_error: 0.6015
# Epoch 42/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6714 - mean_absolute_error: 0.6714
# Epoch 43/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6038 - mean_absolute_error: 0.6038
# Epoch 44/500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6005 - mean_absolute_error: 0.6005
# Epoch 45/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6222 - mean_absolute_error: 0.6222
# Epoch 46/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5835 - mean_absolute_error: 0.5835
# Epoch 47/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.5986 - mean_absolute_error: 0.5986
# Epoch 48/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6234 - mean_absolute_error: 0.6234
# Epoch 49/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6186 - mean_absolute_error: 0.6186
# Epoch 50/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6092 - mean_absolute_error: 0.6092
# Epoch 51/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6083 - mean_absolute_error: 0.6083
# Epoch 52/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6363 - mean_absolute_error: 0.6363
# Epoch 53/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5934 - mean_absolute_error: 0.5934
# Epoch 54/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6083 - mean_absolute_error: 0.6083
# Epoch 55/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6307 - mean_absolute_error: 0.6307
# Epoch 56/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5876 - mean_absolute_error: 0.5876
# Epoch 57/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5962 - mean_absolute_error: 0.5962
# Epoch 58/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5871 - mean_absolute_error: 0.5871
# Epoch 59/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6089 - mean_absolute_error: 0.6089
# Epoch 60/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6433 - mean_absolute_error: 0.6433
# Epoch 61/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6185 - mean_absolute_error: 0.6185
# Epoch 62/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.5997 - mean_absolute_error: 0.5997
# Epoch 63/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.5924 - mean_absolute_error: 0.5924
# Epoch 64/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.5834 - mean_absolute_error: 0.5834
# Epoch 65/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6006 - mean_absolute_error: 0.6006
# Epoch 66/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.5654 - mean_absolute_error: 0.5654
# Epoch 67/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.5845 - mean_absolute_error: 0.5845
# Epoch 68/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5667 - mean_absolute_error: 0.5667
# Epoch 69/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.5668 - mean_absolute_error: 0.5668
# Epoch 70/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.5577 - mean_absolute_error: 0.5577
# Epoch 71/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.5440 - mean_absolute_error: 0.5440
# Epoch 72/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.5700 - mean_absolute_error: 0.5700
# Epoch 73/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.5576 - mean_absolute_error: 0.5576
# Epoch 74/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.5697 - mean_absolute_error: 0.5697
# Epoch 75/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.5551 - mean_absolute_error: 0.5551
# Epoch 76/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.5699 - mean_absolute_error: 0.5699
# Epoch 77/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6639 - mean_absolute_error: 0.6639
# Epoch 78/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.5968 - mean_absolute_error: 0.5968
# Epoch 79/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.5626 - mean_absolute_error: 0.5626
# Epoch 80/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.5698 - mean_absolute_error: 0.5698
# Epoch 81/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.5854 - mean_absolute_error: 0.5854
# Epoch 82/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5767 - mean_absolute_error: 0.5767
# Epoch 83/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5536 - mean_absolute_error: 0.5536
# Epoch 84/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5503 - mean_absolute_error: 0.5503
# Epoch 85/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5617 - mean_absolute_error: 0.5617
# Epoch 86/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.5451 - mean_absolute_error: 0.5451
# Epoch 87/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.5584 - mean_absolute_error: 0.5584
# Epoch 88/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5572 - mean_absolute_error: 0.5572
# Epoch 89/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.5585 - mean_absolute_error: 0.5585
# Epoch 90/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5708 - mean_absolute_error: 0.5708
# Epoch 91/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.5456 - mean_absolute_error: 0.5456
# Epoch 92/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.5275 - mean_absolute_error: 0.5275
# Epoch 93/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.5677 - mean_absolute_error: 0.5677
# Epoch 94/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.5288 - mean_absolute_error: 0.5288
# Epoch 95/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5522 - mean_absolute_error: 0.5522
# Epoch 96/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5412 - mean_absolute_error: 0.5412
# Epoch 97/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.5411 - mean_absolute_error: 0.5411
# Epoch 98/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5449 - mean_absolute_error: 0.5449
# Epoch 99/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.5388 - mean_absolute_error: 0.5388
# Epoch 100/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.5434 - mean_absolute_error: 0.5434
# Epoch 101/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.5984 - mean_absolute_error: 0.5984
# Epoch 102/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5682 - mean_absolute_error: 0.5682
# Epoch 103/500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.5559 - mean_absolute_error: 0.5559
# Epoch 104/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.5329 - mean_absolute_error: 0.5329
# Epoch 105/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.5263 - mean_absolute_error: 0.5263
# Epoch 106/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.5267 - mean_absolute_error: 0.5267
# Epoch 107/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.4930 - mean_absolute_error: 0.4930
# Epoch 108/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.5636 - mean_absolute_error: 0.5636
# Epoch 109/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.5353 - mean_absolute_error: 0.5353
# Epoch 110/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.5326 - mean_absolute_error: 0.5326
# Epoch 111/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5186 - mean_absolute_error: 0.5186
# Epoch 112/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4999 - mean_absolute_error: 0.4999
# Epoch 113/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.5343 - mean_absolute_error: 0.5343
# Epoch 114/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5070 - mean_absolute_error: 0.5070
# Epoch 115/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.4904 - mean_absolute_error: 0.4904
# Epoch 116/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.5054 - mean_absolute_error: 0.5054
# Epoch 117/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4773 - mean_absolute_error: 0.4773
# Epoch 118/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5498 - mean_absolute_error: 0.5498
# Epoch 119/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.5359 - mean_absolute_error: 0.5359
# Epoch 120/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.4818 - mean_absolute_error: 0.4818
# Epoch 121/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4757 - mean_absolute_error: 0.4757
# Epoch 122/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.4786 - mean_absolute_error: 0.4786
# Epoch 123/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.4916 - mean_absolute_error: 0.4916
# Epoch 124/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.4989 - mean_absolute_error: 0.4989
# Epoch 125/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.4679 - mean_absolute_error: 0.4679
# Epoch 126/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5592 - mean_absolute_error: 0.5592
# Epoch 127/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4726 - mean_absolute_error: 0.4726
# Epoch 128/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5258 - mean_absolute_error: 0.5258
# Epoch 129/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.4903 - mean_absolute_error: 0.4903
# Epoch 130/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.4608 - mean_absolute_error: 0.4608
# Epoch 131/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.4616 - mean_absolute_error: 0.4616
# Epoch 132/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.4475 - mean_absolute_error: 0.4475
# Epoch 133/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.4645 - mean_absolute_error: 0.4645
# Epoch 134/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.4410 - mean_absolute_error: 0.4410
# Epoch 135/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.4826 - mean_absolute_error: 0.4826
# Epoch 136/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3986 - mean_absolute_error: 0.3986
# Epoch 137/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.4318 - mean_absolute_error: 0.4318
# Epoch 138/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.4311 - mean_absolute_error: 0.4311
# Epoch 139/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3998 - mean_absolute_error: 0.3998
# Epoch 140/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.4202 - mean_absolute_error: 0.4202
# Epoch 141/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3926 - mean_absolute_error: 0.3926
# Epoch 142/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.4158 - mean_absolute_error: 0.4158
# Epoch 143/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.4435 - mean_absolute_error: 0.4435
# Epoch 144/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.4774 - mean_absolute_error: 0.4774
# Epoch 145/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.4091 - mean_absolute_error: 0.4091
# Epoch 146/500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.3982 - mean_absolute_error: 0.3982
# Epoch 147/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.4119 - mean_absolute_error: 0.4119
# Epoch 148/500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.3902 - mean_absolute_error: 0.3902
# Epoch 149/500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.3644 - mean_absolute_error: 0.3644
# Epoch 150/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3738 - mean_absolute_error: 0.3738
# Epoch 151/500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.3852 - mean_absolute_error: 0.3852
# Epoch 152/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3266 - mean_absolute_error: 0.3266
# Epoch 153/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3874 - mean_absolute_error: 0.3874
# Epoch 154/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.4424 - mean_absolute_error: 0.4424
# Epoch 155/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4056 - mean_absolute_error: 0.4056
# Epoch 156/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.3505 - mean_absolute_error: 0.3505
# Epoch 157/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3814 - mean_absolute_error: 0.3814
# Epoch 158/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.3634 - mean_absolute_error: 0.3634
# Epoch 159/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3860 - mean_absolute_error: 0.3860
# Epoch 160/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.3514 - mean_absolute_error: 0.3514
# Epoch 161/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3776 - mean_absolute_error: 0.3776
# Epoch 162/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3090 - mean_absolute_error: 0.3090
# Epoch 163/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2868 - mean_absolute_error: 0.2868
# Epoch 164/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.3395 - mean_absolute_error: 0.3395
# Epoch 165/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3206 - mean_absolute_error: 0.3206
# Epoch 166/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.3533 - mean_absolute_error: 0.3533
# Epoch 167/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.3172 - mean_absolute_error: 0.3172
# Epoch 168/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.4419 - mean_absolute_error: 0.4419
# Epoch 169/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3353 - mean_absolute_error: 0.3353
# Epoch 170/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3054 - mean_absolute_error: 0.3054
# Epoch 171/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.3259 - mean_absolute_error: 0.3259
# Epoch 172/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3453 - mean_absolute_error: 0.3453
# Epoch 173/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.3030 - mean_absolute_error: 0.3030
# Epoch 174/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.3267 - mean_absolute_error: 0.3267
# Epoch 175/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3108 - mean_absolute_error: 0.3108
# Epoch 176/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3418 - mean_absolute_error: 0.3418
# Epoch 177/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.4722 - mean_absolute_error: 0.4722
# Epoch 178/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3402 - mean_absolute_error: 0.3402
# Epoch 179/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3368 - mean_absolute_error: 0.3368
# Epoch 180/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.2865 - mean_absolute_error: 0.2865
# Epoch 181/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2801 - mean_absolute_error: 0.2801
# Epoch 182/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.3309 - mean_absolute_error: 0.3309
# Epoch 183/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2818 - mean_absolute_error: 0.2818
# Epoch 184/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.2593 - mean_absolute_error: 0.2593
# Epoch 185/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.3695 - mean_absolute_error: 0.3695
# Epoch 186/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.2547 - mean_absolute_error: 0.2547
# Epoch 187/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2484 - mean_absolute_error: 0.2484
# Epoch 188/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2241 - mean_absolute_error: 0.2241
# Epoch 189/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.2742 - mean_absolute_error: 0.2742
# Epoch 190/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3117 - mean_absolute_error: 0.3117
# Epoch 191/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3438 - mean_absolute_error: 0.3438
# Epoch 192/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.2839 - mean_absolute_error: 0.2839
# Epoch 193/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2037 - mean_absolute_error: 0.2037
# Epoch 194/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.3133 - mean_absolute_error: 0.3133
# Epoch 195/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3339 - mean_absolute_error: 0.3339
# Epoch 196/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2169 - mean_absolute_error: 0.2169
# Epoch 197/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2308 - mean_absolute_error: 0.2308
# Epoch 198/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2824 - mean_absolute_error: 0.2824
# Epoch 199/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2669 - mean_absolute_error: 0.2669
# Epoch 200/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2167 - mean_absolute_error: 0.2167
# Epoch 201/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2631 - mean_absolute_error: 0.2631
# Epoch 202/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2315 - mean_absolute_error: 0.2315
# Epoch 203/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.3348 - mean_absolute_error: 0.3348
# Epoch 204/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.3075 - mean_absolute_error: 0.3075
# Epoch 205/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2627 - mean_absolute_error: 0.2627
# Epoch 206/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2211 - mean_absolute_error: 0.2211
# Epoch 207/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1925 - mean_absolute_error: 0.1925
# Epoch 208/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.3377 - mean_absolute_error: 0.3377
# Epoch 209/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2353 - mean_absolute_error: 0.2353
# Epoch 210/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2090 - mean_absolute_error: 0.2090
# Epoch 211/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.2014 - mean_absolute_error: 0.2014
# Epoch 212/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.3353 - mean_absolute_error: 0.3353
# Epoch 213/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2833 - mean_absolute_error: 0.2833
# Epoch 214/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2149 - mean_absolute_error: 0.2149
# Epoch 215/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2664 - mean_absolute_error: 0.2664
# Epoch 216/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2895 - mean_absolute_error: 0.2895
# Epoch 217/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.3004 - mean_absolute_error: 0.3004
# Epoch 218/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2922 - mean_absolute_error: 0.2922
# Epoch 219/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2748 - mean_absolute_error: 0.2748
# Epoch 220/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2547 - mean_absolute_error: 0.2547
# Epoch 221/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1967 - mean_absolute_error: 0.1967
# Epoch 222/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2308 - mean_absolute_error: 0.2308
# Epoch 223/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1353 - mean_absolute_error: 0.1353
# Epoch 224/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2786 - mean_absolute_error: 0.2786
# Epoch 225/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1973 - mean_absolute_error: 0.1973
# Epoch 226/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2196 - mean_absolute_error: 0.2196
# Epoch 227/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1706 - mean_absolute_error: 0.1706
# Epoch 228/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2103 - mean_absolute_error: 0.2103
# Epoch 229/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2197 - mean_absolute_error: 0.2197
# Epoch 230/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1827 - mean_absolute_error: 0.1827
# Epoch 231/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1913 - mean_absolute_error: 0.1913
# Epoch 232/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2233 - mean_absolute_error: 0.2233
# Epoch 233/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1723 - mean_absolute_error: 0.1723
# Epoch 234/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2283 - mean_absolute_error: 0.2283
# Epoch 235/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2152 - mean_absolute_error: 0.2152
# Epoch 236/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1991 - mean_absolute_error: 0.1991
# Epoch 237/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2686 - mean_absolute_error: 0.2686
# Epoch 238/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2473 - mean_absolute_error: 0.2473
# Epoch 239/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2329 - mean_absolute_error: 0.2329
# Epoch 240/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1875 - mean_absolute_error: 0.1875
# Epoch 241/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1471 - mean_absolute_error: 0.1471
# Epoch 242/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1955 - mean_absolute_error: 0.1955
# Epoch 243/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1766 - mean_absolute_error: 0.1766
# Epoch 244/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1962 - mean_absolute_error: 0.1962
# Epoch 245/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2843 - mean_absolute_error: 0.2843
# Epoch 246/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2692 - mean_absolute_error: 0.2692
# Epoch 247/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1909 - mean_absolute_error: 0.1909
# Epoch 248/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2651 - mean_absolute_error: 0.2651
# Epoch 249/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1660 - mean_absolute_error: 0.1660
# Epoch 250/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2369 - mean_absolute_error: 0.2369
# Epoch 251/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1615 - mean_absolute_error: 0.1615
# Epoch 252/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1928 - mean_absolute_error: 0.1928
# Epoch 253/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2348 - mean_absolute_error: 0.2348
# Epoch 254/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3090 - mean_absolute_error: 0.3090
# Epoch 255/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2041 - mean_absolute_error: 0.2041
# Epoch 256/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2229 - mean_absolute_error: 0.2229
# Epoch 257/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1873 - mean_absolute_error: 0.1873
# Epoch 258/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2324 - mean_absolute_error: 0.2324
# Epoch 259/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2465 - mean_absolute_error: 0.2465
# Epoch 260/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1469 - mean_absolute_error: 0.1469
# Epoch 261/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2042 - mean_absolute_error: 0.2042
# Epoch 262/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2546 - mean_absolute_error: 0.2546
# Epoch 263/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2666 - mean_absolute_error: 0.2666
# Epoch 264/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.2532 - mean_absolute_error: 0.2532
# Epoch 265/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.1970 - mean_absolute_error: 0.1970
# Epoch 266/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1834 - mean_absolute_error: 0.1834
# Epoch 267/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.1460 - mean_absolute_error: 0.1460
# Epoch 268/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1321 - mean_absolute_error: 0.1321
# Epoch 269/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1792 - mean_absolute_error: 0.1792
# Epoch 270/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2507 - mean_absolute_error: 0.2507
# Epoch 271/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1884 - mean_absolute_error: 0.1884
# Epoch 272/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2045 - mean_absolute_error: 0.2045
# Epoch 273/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2204 - mean_absolute_error: 0.2204
# Epoch 274/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1639 - mean_absolute_error: 0.1639
# Epoch 275/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1808 - mean_absolute_error: 0.1808
# Epoch 276/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1453 - mean_absolute_error: 0.1453
# Epoch 277/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2115 - mean_absolute_error: 0.2115
# Epoch 278/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.3114 - mean_absolute_error: 0.3114
# Epoch 279/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2525 - mean_absolute_error: 0.2525
# Epoch 280/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2597 - mean_absolute_error: 0.2597
# Epoch 281/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1362 - mean_absolute_error: 0.1362
# Epoch 282/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.1470 - mean_absolute_error: 0.1470
# Epoch 283/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2559 - mean_absolute_error: 0.2559
# Epoch 284/500
# 1/1 [==============================] - 0s 42ms/step - loss: 0.1938 - mean_absolute_error: 0.1938
# Epoch 285/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2365 - mean_absolute_error: 0.2365
# Epoch 286/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1308 - mean_absolute_error: 0.1308
# Epoch 287/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1970 - mean_absolute_error: 0.1970
# Epoch 288/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1906 - mean_absolute_error: 0.1906
# Epoch 289/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1913 - mean_absolute_error: 0.1913
# Epoch 290/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2213 - mean_absolute_error: 0.2213
# Epoch 291/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1715 - mean_absolute_error: 0.1715
# Epoch 292/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1691 - mean_absolute_error: 0.1691
# Epoch 293/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1992 - mean_absolute_error: 0.1992
# Epoch 294/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1191 - mean_absolute_error: 0.1191
# Epoch 295/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2316 - mean_absolute_error: 0.2316
# Epoch 296/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2040 - mean_absolute_error: 0.2040
# Epoch 297/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1357 - mean_absolute_error: 0.1357
# Epoch 298/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1873 - mean_absolute_error: 0.1873
# Epoch 299/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1635 - mean_absolute_error: 0.1635
# Epoch 300/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1442 - mean_absolute_error: 0.1442
# Epoch 301/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1361 - mean_absolute_error: 0.1361
# Epoch 302/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1625 - mean_absolute_error: 0.1625
# Epoch 303/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1593 - mean_absolute_error: 0.1593
# Epoch 304/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1945 - mean_absolute_error: 0.1945
# Epoch 305/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1610 - mean_absolute_error: 0.1610
# Epoch 306/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1734 - mean_absolute_error: 0.1734
# Epoch 307/500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1702 - mean_absolute_error: 0.1702
# Epoch 308/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.1521 - mean_absolute_error: 0.1521
# Epoch 309/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.1552 - mean_absolute_error: 0.1552
# Epoch 310/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.1851 - mean_absolute_error: 0.1851
# Epoch 311/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1621 - mean_absolute_error: 0.1621
# Epoch 312/500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1826 - mean_absolute_error: 0.1826
# Epoch 313/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1048 - mean_absolute_error: 0.1048
# Epoch 314/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1404 - mean_absolute_error: 0.1404
# Epoch 315/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2183 - mean_absolute_error: 0.2183
# Epoch 316/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.1518 - mean_absolute_error: 0.1518
# Epoch 317/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1492 - mean_absolute_error: 0.1492
# Epoch 318/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.1414 - mean_absolute_error: 0.1414
# Epoch 319/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1286 - mean_absolute_error: 0.1286
# Epoch 320/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1350 - mean_absolute_error: 0.1350
# Epoch 321/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1255 - mean_absolute_error: 0.1255
# Epoch 322/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0950 - mean_absolute_error: 0.0950
# Epoch 323/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1953 - mean_absolute_error: 0.1953
# Epoch 324/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1713 - mean_absolute_error: 0.1713
# Epoch 325/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1442 - mean_absolute_error: 0.1442
# Epoch 326/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1132 - mean_absolute_error: 0.1132
# Epoch 327/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1446 - mean_absolute_error: 0.1446
# Epoch 328/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2700 - mean_absolute_error: 0.2700
# Epoch 329/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1578 - mean_absolute_error: 0.1578
# Epoch 330/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1568 - mean_absolute_error: 0.1568
# Epoch 331/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1084 - mean_absolute_error: 0.1084
# Epoch 332/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1176 - mean_absolute_error: 0.1176
# Epoch 333/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1215 - mean_absolute_error: 0.1215
# Epoch 334/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1987 - mean_absolute_error: 0.1987
# Epoch 335/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1175 - mean_absolute_error: 0.1175
# Epoch 336/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1875 - mean_absolute_error: 0.1875
# Epoch 337/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2553 - mean_absolute_error: 0.2553
# Epoch 338/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1651 - mean_absolute_error: 0.1651
# Epoch 339/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1190 - mean_absolute_error: 0.1190
# Epoch 340/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1561 - mean_absolute_error: 0.1561
# Epoch 341/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1805 - mean_absolute_error: 0.1805
# Epoch 342/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1205 - mean_absolute_error: 0.1205
# Epoch 343/500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1553 - mean_absolute_error: 0.1553
# Epoch 344/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1392 - mean_absolute_error: 0.1392
# Epoch 345/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0846 - mean_absolute_error: 0.0846
# Epoch 346/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1450 - mean_absolute_error: 0.1450
# Epoch 347/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.1129 - mean_absolute_error: 0.1129
# Epoch 348/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.2738 - mean_absolute_error: 0.2738
# Epoch 349/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.2525 - mean_absolute_error: 0.2525
# Epoch 350/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.1506 - mean_absolute_error: 0.1506
# Epoch 351/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1515 - mean_absolute_error: 0.1515
# Epoch 352/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.1477 - mean_absolute_error: 0.1477
# Epoch 353/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2122 - mean_absolute_error: 0.2122
# Epoch 354/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.1223 - mean_absolute_error: 0.1223
# Epoch 355/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1654 - mean_absolute_error: 0.1654
# Epoch 356/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.1127 - mean_absolute_error: 0.1127
# Epoch 357/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.1315 - mean_absolute_error: 0.1315
# Epoch 358/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1539 - mean_absolute_error: 0.1539
# Epoch 359/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1408 - mean_absolute_error: 0.1408
# Epoch 360/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2118 - mean_absolute_error: 0.2118
# Epoch 361/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1312 - mean_absolute_error: 0.1312
# Epoch 362/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2048 - mean_absolute_error: 0.2048
# Epoch 363/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1367 - mean_absolute_error: 0.1367
# Epoch 364/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1517 - mean_absolute_error: 0.1517
# Epoch 365/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1258 - mean_absolute_error: 0.1258
# Epoch 366/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1449 - mean_absolute_error: 0.1449
# Epoch 367/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1838 - mean_absolute_error: 0.1838
# Epoch 368/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1034 - mean_absolute_error: 0.1034
# Epoch 369/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1488 - mean_absolute_error: 0.1488
# Epoch 370/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1272 - mean_absolute_error: 0.1272
# Epoch 371/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1201 - mean_absolute_error: 0.1201
# Epoch 372/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1112 - mean_absolute_error: 0.1112
# Epoch 373/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1048 - mean_absolute_error: 0.1048
# Epoch 374/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0863 - mean_absolute_error: 0.0863
# Epoch 375/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1496 - mean_absolute_error: 0.1496
# Epoch 376/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1287 - mean_absolute_error: 0.1287
# Epoch 377/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1205 - mean_absolute_error: 0.1205
# Epoch 378/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1642 - mean_absolute_error: 0.1642
# Epoch 379/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1566 - mean_absolute_error: 0.1566
# Epoch 380/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1333 - mean_absolute_error: 0.1333
# Epoch 381/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1528 - mean_absolute_error: 0.1528
# Epoch 382/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1731 - mean_absolute_error: 0.1731
# Epoch 383/500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2023 - mean_absolute_error: 0.2023
# Epoch 384/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1753 - mean_absolute_error: 0.1753
# Epoch 385/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0876 - mean_absolute_error: 0.0876
# Epoch 386/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1841 - mean_absolute_error: 0.1841
# Epoch 387/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1202 - mean_absolute_error: 0.1202
# Epoch 388/500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1452 - mean_absolute_error: 0.1452
# Epoch 389/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1287 - mean_absolute_error: 0.1287
# Epoch 390/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1803 - mean_absolute_error: 0.1803
# Epoch 391/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1906 - mean_absolute_error: 0.1906
# Epoch 392/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1394 - mean_absolute_error: 0.1394
# Epoch 393/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1424 - mean_absolute_error: 0.1424
# Epoch 394/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1025 - mean_absolute_error: 0.1025
# Epoch 395/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1862 - mean_absolute_error: 0.1862
# Epoch 396/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2245 - mean_absolute_error: 0.2245
# Epoch 397/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1684 - mean_absolute_error: 0.1684
# Epoch 398/500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1410 - mean_absolute_error: 0.1410
# Epoch 399/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1743 - mean_absolute_error: 0.1743
# Epoch 400/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1999 - mean_absolute_error: 0.1999
# Epoch 401/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2291 - mean_absolute_error: 0.2291
# Epoch 402/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1284 - mean_absolute_error: 0.1284
# Epoch 403/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1812 - mean_absolute_error: 0.1812
# Epoch 404/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1670 - mean_absolute_error: 0.1670
# Epoch 405/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1466 - mean_absolute_error: 0.1466
# Epoch 406/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2503 - mean_absolute_error: 0.2503
# Epoch 407/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1954 - mean_absolute_error: 0.1954
# Epoch 408/500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1451 - mean_absolute_error: 0.1451
# Epoch 409/500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1066 - mean_absolute_error: 0.1066
# Epoch 410/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1693 - mean_absolute_error: 0.1693
# Epoch 411/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1603 - mean_absolute_error: 0.1603
# Epoch 412/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1606 - mean_absolute_error: 0.1606
# Epoch 413/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1751 - mean_absolute_error: 0.1751
# Epoch 414/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1205 - mean_absolute_error: 0.1205
# Epoch 415/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0931 - mean_absolute_error: 0.0931
# Epoch 416/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1173 - mean_absolute_error: 0.1173
# Epoch 417/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1296 - mean_absolute_error: 0.1296
# Epoch 418/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0963 - mean_absolute_error: 0.0963
# Epoch 419/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2213 - mean_absolute_error: 0.2213
# Epoch 420/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1665 - mean_absolute_error: 0.1665
# Epoch 421/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1748 - mean_absolute_error: 0.1748
# Epoch 422/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1177 - mean_absolute_error: 0.1177
# Epoch 423/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1392 - mean_absolute_error: 0.1392
# Epoch 424/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1778 - mean_absolute_error: 0.1778
# Epoch 425/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1662 - mean_absolute_error: 0.1662
# Epoch 426/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1451 - mean_absolute_error: 0.1451
# Epoch 427/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1238 - mean_absolute_error: 0.1238
# Epoch 428/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1288 - mean_absolute_error: 0.1288
# Epoch 429/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.1283 - mean_absolute_error: 0.1283
# Epoch 430/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.1110 - mean_absolute_error: 0.1110
# Epoch 431/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.1256 - mean_absolute_error: 0.1256
# Epoch 432/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1359 - mean_absolute_error: 0.1359
# Epoch 433/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.2055 - mean_absolute_error: 0.2055
# Epoch 434/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1479 - mean_absolute_error: 0.1479
# Epoch 435/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1345 - mean_absolute_error: 0.1345
# Epoch 436/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.1313 - mean_absolute_error: 0.1313
# Epoch 437/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1226 - mean_absolute_error: 0.1226
# Epoch 438/500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1044 - mean_absolute_error: 0.1044
# Epoch 439/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1193 - mean_absolute_error: 0.1193
# Epoch 440/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1492 - mean_absolute_error: 0.1492
# Epoch 441/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1189 - mean_absolute_error: 0.1189
# Epoch 442/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1717 - mean_absolute_error: 0.1717
# Epoch 443/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1540 - mean_absolute_error: 0.1540
# Epoch 444/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1182 - mean_absolute_error: 0.1182
# Epoch 445/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1456 - mean_absolute_error: 0.1456
# Epoch 446/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1742 - mean_absolute_error: 0.1742
# Epoch 447/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1438 - mean_absolute_error: 0.1438
# Epoch 448/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1024 - mean_absolute_error: 0.1024
# Epoch 449/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1562 - mean_absolute_error: 0.1562
# Epoch 450/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1799 - mean_absolute_error: 0.1799
# Epoch 451/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1636 - mean_absolute_error: 0.1636
# Epoch 452/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1413 - mean_absolute_error: 0.1413
# Epoch 453/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1757 - mean_absolute_error: 0.1757
# Epoch 454/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1093 - mean_absolute_error: 0.1093
# Epoch 455/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0746 - mean_absolute_error: 0.0746
# Epoch 456/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1114 - mean_absolute_error: 0.1114
# Epoch 457/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0694 - mean_absolute_error: 0.0694
# Epoch 458/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1500 - mean_absolute_error: 0.1500
# Epoch 459/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0812 - mean_absolute_error: 0.0812
# Epoch 460/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1273 - mean_absolute_error: 0.1273
# Epoch 461/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1531 - mean_absolute_error: 0.1531
# Epoch 462/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0957 - mean_absolute_error: 0.0957
# Epoch 463/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1329 - mean_absolute_error: 0.1329
# Epoch 464/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1336 - mean_absolute_error: 0.1336
# Epoch 465/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0957 - mean_absolute_error: 0.0957
# Epoch 466/500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1863 - mean_absolute_error: 0.1863
# Epoch 467/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0990 - mean_absolute_error: 0.0990
# Epoch 468/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0981 - mean_absolute_error: 0.0981
# Epoch 469/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2013 - mean_absolute_error: 0.2013
# Epoch 470/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.1443 - mean_absolute_error: 0.1443
# Epoch 471/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0783 - mean_absolute_error: 0.0783
# Epoch 472/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1105 - mean_absolute_error: 0.1105
# Epoch 473/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1421 - mean_absolute_error: 0.1421
# Epoch 474/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1190 - mean_absolute_error: 0.1190
# Epoch 475/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.1583 - mean_absolute_error: 0.1583
# Epoch 476/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1363 - mean_absolute_error: 0.1363
# Epoch 477/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.1457 - mean_absolute_error: 0.1457
# Epoch 478/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1320 - mean_absolute_error: 0.1320
# Epoch 479/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1134 - mean_absolute_error: 0.1134
# Epoch 480/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1353 - mean_absolute_error: 0.1353
# Epoch 481/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1358 - mean_absolute_error: 0.1358
# Epoch 482/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1080 - mean_absolute_error: 0.1080
# Epoch 483/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1649 - mean_absolute_error: 0.1649
# Epoch 484/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0951 - mean_absolute_error: 0.0951
# Epoch 485/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1155 - mean_absolute_error: 0.1155
# Epoch 486/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1662 - mean_absolute_error: 0.1662
# Epoch 487/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1232 - mean_absolute_error: 0.1232
# Epoch 488/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0969 - mean_absolute_error: 0.0969
# Epoch 489/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1527 - mean_absolute_error: 0.1527
# Epoch 490/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0885 - mean_absolute_error: 0.0885
# Epoch 491/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0997 - mean_absolute_error: 0.0997
# Epoch 492/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0820 - mean_absolute_error: 0.0820
# Epoch 493/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1311 - mean_absolute_error: 0.1311
# Epoch 494/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1242 - mean_absolute_error: 0.1242
# Epoch 495/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0834 - mean_absolute_error: 0.0834
# Epoch 496/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1574 - mean_absolute_error: 0.1574
# Epoch 497/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1135 - mean_absolute_error: 0.1135
# Epoch 498/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1578 - mean_absolute_error: 0.1578
# Epoch 499/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1515 - mean_absolute_error: 0.1515
# Epoch 500/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1180 - mean_absolute_error: 0.1180

# %%
# loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-afff23f49c13> in <cell line: 3>()
#       1 # loss
#       2 plt.plot(history.history['loss'])
# ----> 3 plt.plot(history.history['val_loss'])
#       4 plt.title('model loss')
#       5 plt.ylabel('loss')
#
# KeyError: 'val_loss'

# %%
# accuracy
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('MAE vs Epoch')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
loss, accuracy = model.evaluate(x, y)
# Out:
# 1/1 [==============================] - 0s 77ms/step - loss: 0.1029 - mean_absolute_error: 0.1029

# %%
y_pred = model.predict(x)
# Out:
# 1/1 [==============================] - 0s 385ms/step

# %%
y
# Out:
#     roff_rv        ron_rv     vs    vr
# 0  0.000007  8.804207e-09  2.000 -1.68
# 1  0.005373  3.050072e-08  1.750 -1.00
# 2  0.000663  3.682850e-08  0.750 -0.75
# 3  0.000256  5.926848e-06  0.877 -1.50
# 4  0.000407  2.387368e-05  0.580 -1.50
# 5  0.000647  1.113548e-04  0.660 -1.50

# %%
y_pred
# Out:
# array([[ 2.2207235e-03,  1.0768417e-03,  2.0144308e+00, -1.7383513e+00],
#        [ 2.3264359e-03,  5.4999092e-04,  1.1372768e+00, -8.1958091e-01],
#        [ 2.2380161e-03,  5.4342533e-04,  1.0948446e+00, -8.3249319e-01],
#        [ 8.8965194e-04,  5.5589032e-04,  6.4314777e-01, -1.2196056e+00],
#        [ 8.9319941e-04,  5.5323378e-04,  6.3978314e-01, -1.2141545e+00],
#        [ 8.9437416e-04,  5.5378693e-04,  6.4115536e-01, -1.2147701e+00]],
#       dtype=float32)

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

# Get predicted values from the model
predicted_values = model.predict(x)

# True labels
true_values = y

# Calculate regression metrics
mse = mean_squared_error(true_values, predicted_values)
rmse = np.sqrt(mse)
mae = mean_absolute_error(true_values, predicted_values)
r2 = r2_score(true_values, predicted_values)

print('Mean Squared Error:', mse)
print('Root Mean Squared Error:', rmse)
print('Mean Absolute Error:', mae)
print('R-squared:', r2)
# Out:
# 1/1 [==============================] - 0s 51ms/step
# Mean Squared Error: 0.034901565019364034
# Root Mean Squared Error: 0.18681960555403182
# Mean Absolute Error: 0.10287946509714192
# R-squared: -64.87465894289855

# %%
model.predict([[14	,7,	1.000,	6,	1,	0]])
# Out:
# 1/1 [==============================] - 0s 75ms/step
# array([[ 8.9437410e-04,  5.5378693e-04,  6.4115536e-01, -1.2147701e+00]],
#       dtype=float32)

# %%
#INVERSE DESIGN
# !pip install bayesian-optimization pyswarm deap nevergrad
# Out:
# Collecting bayesian-optimization
#   Downloading bayesian_optimization-1.4.3-py3-none-any.whl (18 kB)
# Collecting pyswarm
#   Downloading pyswarm-0.6.tar.gz (4.3 kB)
#   Preparing metadata (setup.py) ... done
# Collecting deap
#   Downloading deap-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.4/135.4 kB 7.1 MB/s eta 0:00:00
# Collecting nevergrad
#   Downloading nevergrad-1.0.2-py3-none-any.whl (487 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.5/487.5 kB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from bayesian-optimization) (1.25.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bayesian-optimization) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from bayesian-optimization) (1.2.2)
# Collecting colorama>=0.4.6 (from bayesian-optimization)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting cma>=2.6.0 (from nevergrad)
#   Downloading cma-3.3.0-py3-none-any.whl (260 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.7/260.7 kB 11.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from nevergrad) (4.12.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from nevergrad) (2.0.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18.0->bayesian-optimization) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18.0->bayesian-optimization) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->nevergrad) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->nevergrad) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->nevergrad) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->nevergrad) (1.16.0)
# Building wheels for collected packages: pyswarm
#   Building wheel for pyswarm (setup.py) ... done
#   Created wheel for pyswarm: filename=pyswarm-0.6-py3-none-any.whl size=4464 sha256=0c471adb39d8cd9c38c4d28ef49d362b2db0ae63361cd3a7da5ff2f832b879f6
#   Stored in directory: /root/.cache/pip/wheels/71/67/40/62fa158f497f942277cbab8199b05cb61c571ab324e67ad0d6
# Successfully built pyswarm
# Installing collected packages: pyswarm, deap, colorama, cma, bayesian-optimization, nevergrad
# Successfully installed bayesian-optimization-1.4.3 cma-3.3.0 colorama-0.4.6 deap-1.4.1 nevergrad-1.0.2 pyswarm-0.6

# %%
y
# Out:
#     roff_rv        ron_rv     vs    vr
# 0  0.000007  8.804207e-09  2.000 -1.68
# 1  0.005373  3.050072e-08  1.750 -1.00
# 2  0.000663  3.682850e-08  0.750 -0.75
# 3  0.000256  5.926848e-06  0.877 -1.50
# 4  0.000407  2.387368e-05  0.580 -1.50
# 5  0.000647  1.113548e-04  0.660 -1.50

# %%
x
# Out:
#    mname  mthickness (nm)  cellarea (µm2)  topelectrode  bottomelectrode  \
# 0     11                6           0.053             1                2
# 1     12                1         100.000             3                4
# 2     13                1         100.000             3                5
# 3     14                3           1.000             6                1
# 4     14                5           1.000             6                1
# 5     14                7           1.000             6                1
#
#    extrastack
# 0           6
# 1           0
# 2           4
# 3           0
# 4           0
# 5           0

# %%
# Au = 1, W = 2, Mo = 3, Sn = 4, Pt = 5, Ti = 6,
# H-BN = 11, MoS2 = 12, MoSe2 = 13,PdSe2 = 14

# %%
# from scipy.optimize import minimize
# # Desired target output
# target_output = np.array([0.000256, 5.926848e-06, 0.877, -1.50])

# # Define the loss function for optimization
# def loss_function(x):
#     x = np.array(x).reshape(1, -1)
#     predicted_output = model.predict(x)
#     loss = np.mean(np.abs(predicted_output - target_output))
#     return loss

# # Initial guess for the input parameters (can be random or based on domain knowledge)
# # initial_guess = np.array([14, 3, 1, 6, 1, 0])
# def generate_random_initial_guess(bounds):
#     return [np.random.uniform(low, high) for low, high in bounds]

# # Bounds for the input parameters (if applicable)
# bounds = [(11, 14), (1, 6), (0.053, 100.000), (1, 6), (1, 6), (0, 6)]


# initial_guess = generate_random_initial_guess(bounds)

# # Perform the optimization
# result = minimize(loss_function, initial_guess, bounds=bounds, method='L-BFGS-B')

# # Optimized input parameters
# optimized_input = result.x

# print("Optimized Input Parameters:")
# print(optimized_input)

# %%
import tensorflow as tf
import numpy as np

# Define the neural network architecture
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(256, activation='relu', input_shape=(6,)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(4)  # No activation for linear output
])

# Example target output
target_output = np.array([0.000256, 5.926848e-06, 0.877, -1.50])

# Function to calculate loss (mean squared error)
def loss_function(inputs):
    predicted_output = model(tf.expand_dims(inputs, axis=0))
    loss = tf.reduce_mean(tf.square(target_output - predicted_output))
    return loss

# Optimization process using gradient descent optimizer
optimizer = tf.keras.optimizers.Adam()

# Number of iterations for optimization
iterations = 1000

# Initial guess for input parameters (param1 to param6)
initial_inputs = np.array([12.0, 3.0, 50.0, 2.0, 4.0, 3.0], dtype=np.float32)

# TensorFlow variable for inputs
inputs = tf.Variable(initial_inputs, dtype=tf.float32, trainable=True)

# Gradient tape optimization loop
for i in range(iterations):
    with tf.GradientTape() as tape:
        current_loss = loss_function(inputs)

    gradients = tape.gradient(current_loss, [inputs])
    optimizer.apply_gradients(zip(gradients, [inputs]))

    if i % 100 == 0:
        print(f"Iteration {i}: Loss = {current_loss.numpy()}")

# Print optimized inputs
print("Optimized Inputs:")
print(inputs.numpy())

# Predict output with optimized inputs
predicted_output = model(tf.expand_dims(inputs, axis=0)).numpy().flatten()
print("Predicted Output:")
print(predicted_output)
# Out:
# Iteration 0: Loss = 0.8128235936164856
# Iteration 100: Loss = 0.8120337128639221
# Iteration 200: Loss = 0.8112380504608154
# Iteration 300: Loss = 0.8105266094207764
# Iteration 400: Loss = 0.8098544478416443
# Iteration 500: Loss = 0.8092271089553833
# Iteration 600: Loss = 0.808574378490448
# Iteration 700: Loss = 0.8078649044036865
# Iteration 800: Loss = 0.8071130514144897
# Iteration 900: Loss = 0.8059460520744324
# Optimized Inputs:
# [12.005882    3.981369   48.97374     0.92508566  3.0015297   2.0270095 ]
# Predicted Output:
# [ 0.2115626  -0.08850079  0.01577693  0.0574944 ]

# %%
# int/float, range
from scipy.optimize import minimize
import numpy as np

target_output = np.array([0.000256, 5.926848e-06, 0.877, -1.50])

# Weighted Loss Function, mse etc
def loss_function(x):
    x = np.array(x).reshape(1, -1)
    predicted_output = model.predict(x)
    loss = np.mean(np.abs(predicted_output - target_output))
    return loss

# Generate random initial guess within the bounds
def generate_random_initial_guess(bounds):
    initial_guess = []
    for param, bound in bounds.items():
        if isinstance(bound[0], int):
            initial_guess.append(np.random.randint(bound[0], bound[1] + 1))  # Integer bounds
        else:
            initial_guess.append(np.random.uniform(bound[0], bound[1]))  # Float bounds
    return initial_guess

# Define bounds for different types of variables
bounds = {
    'param1': (11, 14),
    'param2': (1, 6),
    'param3': (0.053, 100.000),
    'param4': (1, 6) ,
    'param5': (1, 6) ,
    'param6': (0, 6)
}

# Generate random initial guess with integer and float bounds
initial_guess = generate_random_initial_guess(bounds)

#Differential Evolution or Particle Swarm Optimization, which are less likely to get stuck in local minima compared to L-BFGS-B
# Performing the optimization
result = minimize(loss_function, initial_guess, bounds=list(bounds.values()), method='L-BFGS-B')

# Optimized input parameters
optimized_input = result.x

print("Optimized Input Parameters:")
print(optimized_input)
# Out:
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# Optimized Input Parameters:
# [14.         2.         0.8762855  3.         6.         3.       ]

# %%
import tensorflow as tf
import numpy as np
from scipy.optimize import minimize, differential_evolution, shgo, dual_annealing
from pyswarm import pso  # Install this package with `pip install pyswarm`

# Target output
target_output = np.array([0.000256, 5.926848e-06, 0.877, -1.50])

# Weighted Loss Function
def loss_function(x):
    x = np.array(x).reshape(1, -1)
    predicted_output = model.predict(x, verbose=0)
    loss = np.mean(np.abs(predicted_output - target_output))
    return loss

# Generate random initial guess within the bounds
def generate_random_initial_guess(bounds):
    initial_guess = []
    for param, bound in bounds.items():
        if isinstance(bound[0], int):
            initial_guess.append(np.random.randint(bound[0], bound[1] + 1))  # Integer bounds
        else:
            initial_guess.append(np.random.uniform(bound[0], bound[1]))  # Float bounds
    return initial_guess

# Define bounds for different types of variables
bounds = {
    'param1': (11, 14),
    'param2': (1, 6),
    'param3': (0.053, 100.000),
    'param4': (1, 6),
    'param5': (1, 6),
    'param6': (0, 6)
}

# Convert bounds to tuple format for SciPy optimization
tuple_bounds = [(v[0], v[1]) for v in bounds.values()]

# Generate random initial guess with integer and float bounds
initial_guess = generate_random_initial_guess(bounds)

# Function to predict output
def predict_output(optimized_input):
    optimized_input = np.array(optimized_input).reshape(1, -1)
    predicted_output = model.predict(optimized_input, verbose=0)
    return predicted_output

# Optimize using different algorithms
def optimize_with_algorithms():
    results = {}

    # Differential Evolution
    result_de = differential_evolution(loss_function, tuple_bounds, maxiter=50)
    results['Differential Evolution'] = result_de.x

    # Particle Swarm Optimization
    lb = [b[0] for b in tuple_bounds]
    ub = [b[1] for b in tuple_bounds]
    optimized_input_pso, _ = pso(loss_function, lb, ub, maxiter=50)
    results['Particle Swarm Optimization'] = optimized_input_pso

    # Simulated Annealing
    result_sa = dual_annealing(loss_function, bounds=tuple_bounds, maxiter=50)
    results['Simulated Annealing'] = result_sa.x

    # Shgo (Simplicial Homology Global Optimization)
    result_shgo = shgo(loss_function, bounds=tuple_bounds, iters=5)
    results['Shgo'] = result_shgo.x

    return results

optimized_results = optimize_with_algorithms()

for algo, (params, prediction) in optimized_results.items():
    print(f"\nOptimized Input Parameters ({algo}):")
    print(params)
    print(f"Predicted Output ({algo}):")
    print(prediction)
# Out:
# Stopping search: maximum iterations reached --> 50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-cf2542b7dad5> in <cell line: 74>()
#      72 optimized_results = optimize_with_algorithms()
#      73
# ---> 74 for algo, (params, prediction) in optimized_results.items():
#      75     print(f"\nOptimized Input Parameters ({algo}):")
#      76     print(params)
#
# ValueError: too many values to unpack (expected 2)

# %%
import tensorflow as tf
import numpy as np
from scipy.optimize import differential_evolution, shgo, dual_annealing
from sklearn.model_selection import ParameterGrid
from bayes_opt import BayesianOptimization
from pyswarm import pso
import nevergrad as ng
import time

# Target output
target_output = np.array([0.000256, 5.926848e-06, 0.877, -1.50])

# Weighted Loss Function
def loss_function(x):
    x = np.array(x)
    x[0] = int(round(x[0]))
    x[1] = int(round(x[1]))
    x[3] = int(round(x[3]))
    x[4] = int(round(x[4]))
    x[5] = int(round(x[5]))
    x = x.reshape(1, -1)
    predicted_output = model.predict(x, verbose=0)
    loss = np.mean(np.abs(predicted_output - target_output))
    return loss

# Define bounds for different types of variables
bounds = {
    'param1': (11, 14),
    'param2': (1, 6),
    'param3': (0.053, 100.000),
    'param4': (1, 6),
    'param5': (1, 6),
    'param6': (0, 6)
}

# Convert bounds to tuple format for SciPy optimization
tuple_bounds = [(v[0], v[1]) for v in bounds.values()]

# Function to predict output
def predict_output(optimized_input):
    optimized_input = np.array(optimized_input).reshape(1, -1)
    predicted_output = model.predict(optimized_input, verbose=0)
    return predicted_output

# Optimize using different algorithms
def optimize_with_algorithms():
    results = {}

    # Differential Evolution
    start_time = time.time()
    result_de = differential_evolution(loss_function, tuple_bounds, maxiter=50, strategy='best1bin')
    de_params = result_de.x
    de_params[0:1] = np.round(de_params[0:1])
    de_params[3:6] = np.round(de_params[3:6])
    results['Differential Evolution'] = (de_params, predict_output(de_params))
    print(f"Differential Evolution took {time.time() - start_time:.2f} seconds")

    # Particle Swarm Optimization
    start_time = time.time()
    lb = [b[0] for b in tuple_bounds]
    ub = [b[1] for b in tuple_bounds]
    optimized_input_pso, _ = pso(loss_function, lb, ub, swarmsize=10, maxiter=50)
    optimized_input_pso[0:1] = np.round(optimized_input_pso[0:1])
    optimized_input_pso[3:6] = np.round(optimized_input_pso[3:6])
    results['Particle Swarm Optimization'] = (optimized_input_pso, predict_output(optimized_input_pso))
    print(f"Particle Swarm Optimization took {time.time() - start_time:.2f} seconds")

    # Simulated Annealing
    start_time = time.time()
    result_sa = dual_annealing(loss_function, bounds=tuple_bounds, maxiter=50)
    sa_params = result_sa.x
    sa_params[0:1] = np.round(sa_params[0:1])
    sa_params[3:6] = np.round(sa_params[3:6])
    results['Simulated Annealing'] = (sa_params, predict_output(sa_params))
    print(f"Simulated Annealing took {time.time() - start_time:.2f} seconds")

    # Shgo (Simplicial Homology Global Optimization)
    start_time = time.time()
    result_shgo = shgo(loss_function, bounds=tuple_bounds, iters=50)
    shgo_params = result_shgo.x
    shgo_params[0:1] = np.round(shgo_params[0:1])
    shgo_params[3:6] = np.round(shgo_params[3:6])
    results['Shgo'] = (shgo_params, predict_output(shgo_params))
    print(f"Shgo took {time.time() - start_time:.2f} seconds")

    # Grid Search
    start_time = time.time()
    grid = ParameterGrid({
        'param1': range(11, 15),
        'param2': range(1, 7),
        'param3': np.linspace(0.053, 100.000, 3),  # Lower the resolution
        'param4': range(1, 7),
        'param5': range(1, 7),
        'param6': np.linspace(0, 6, 3)  # Lower the resolution
    })
    best_loss = float('inf')
    best_params = None
    for params in grid:
        x = [params[k] for k in sorted(params.keys())]
        loss = loss_function(x)
        if loss < best_loss:
            best_loss = loss
            best_params = x
    results['Grid Search'] = (best_params, predict_output(best_params))
    print(f"Grid Search took {time.time() - start_time:.2f} seconds")

    # Bayesian Optimization
    start_time = time.time()
    def bayesian_function(param1, param2, param3, param4, param5, param6):
        return -loss_function([param1, param2, param3, param4, param5, param6])

    optimizer = BayesianOptimization(
        f=bayesian_function,
        pbounds={
            'param1': bounds['param1'],
            'param2': bounds['param2'],
            'param3': bounds['param3'],
            'param4': bounds['param4'],
            'param5': bounds['param5'],
            'param6': bounds['param6']
        },
        random_state=42,
        allow_duplicate_points=True  # Allow duplicate points
    )
    optimizer.maximize(init_points=5, n_iter=50)  # Reduce the number of iterations
    best_params_bo = optimizer.max['params']
    best_params_bo_array = [best_params_bo[key] for key in sorted(best_params_bo.keys())]
    best_params_bo_array[0:1] = np.round(best_params_bo_array[0:1])
    best_params_bo_array[3:6] = np.round(best_params_bo_array[3:6])
    results['Bayesian Optimization'] = (best_params_bo_array, predict_output(best_params_bo_array))
    print(f"Bayesian Optimization took {time.time() - start_time:.2f} seconds")

    return results

optimized_results = optimize_with_algorithms()

for algo, (params, prediction) in optimized_results.items():
    print(f"\nOptimized Input Parameters ({algo}):")
    print(params)
    print(f"Predicted Output ({algo}):")
    print(prediction)
# Out:
# Differential Evolution took 426.18 seconds
# Stopping search: Swarm best objective change less than 1e-08
# Particle Swarm Optimization took 24.77 seconds
# Simulated Annealing took 53.45 seconds
# Shgo took 683.90 seconds
# Grid Search took 703.62 seconds
# |   iter    |  target   |  param1   |  param2   |  param3   |  param4   |  param5   |  param6   |
# -------------------------------------------------------------------------------------------------
# | 1         | -0.1473   | 12.12     | 5.754     | 73.21     | 3.993     | 1.78      | 0.936     |
# | 2         | -0.1264   | 11.17     | 5.331     | 60.13     | 4.54      | 1.103     | 5.819     |
# | 3         | -0.129    | 13.5      | 2.062     | 18.23     | 1.917     | 2.521     | 3.149     |
# | 4         | -0.1212   | 12.3      | 2.456     | 61.21     | 1.697     | 2.461     | 2.198     |
# | 5         | -0.1315   | 12.37     | 4.926     | 20.01     | 3.571     | 3.962     | 0.2787    |
# | 6         | -0.1332   | 13.16     | 1.0       | 54.92     | 1.0       | 3.289     | 1.355     |
# | 7         | -0.127    | 11.0      | 1.0       | 62.55     | 1.0       | 3.519     | 5.943     |
# | 8         | -0.1171   | 11.0      | 1.0       | 61.6      | 5.522     | 1.0       | 0.558     |
# | 9         | -0.1171   | 11.0      | 1.0       | 61.87     | 6.0       | 6.0       | 0.0       |
# | 10        | -0.1195   | 13.15     | 5.718     | 59.79     | 5.454     | 4.81      | 0.04723   |
# | 11        | -0.1251   | 11.0      | 1.297     | 0.053     | 6.0       | 1.0       | 6.0       |
# | 12        | -0.2355   | 14.0      | 1.0       | 100.0     | 6.0       | 6.0       | 0.4034    |
# | 13        | -0.1323   | 14.0      | 6.0       | 0.053     | 1.0       | 6.0       | 0.0       |
# | 14        | -0.1399   | 14.0      | 6.0       | 10.21     | 6.0       | 1.0       | 6.0       |
# | 15        | -0.1327   | 11.21     | 1.116     | 30.87     | 5.321     | 3.777     | 5.906     |
# | 16        | -0.1065   | 11.0      | 1.0       | 8.146     | 6.0       | 6.0       | 0.0       |
# | 17        | -0.1414   | 11.0      | 1.0       | 8.086     | 1.0       | 6.0       | 6.0       |
# | 18        | -0.1216   | 11.0      | 1.0       | 5.861     | 6.0       | 1.0       | 0.0       |
# | 19        | -0.1215   | 14.0      | 6.0       | 40.69     | 6.0       | 1.0       | 0.0       |
# | 20        | -0.113    | 14.0      | 1.0       | 13.57     | 6.0       | 6.0       | 0.0       |
# | 21        | -0.1302   | 14.0      | 1.0       | 0.053     | 6.0       | 6.0       | 0.0       |
# | 22        | -0.1254   | 14.0      | 6.0       | 40.83     | 1.0       | 6.0       | 6.0       |
# | 23        | -0.1181   | 14.0      | 1.0       | 34.59     | 1.0       | 1.0       | 0.0       |
# | 24        | -0.1316   | 11.0      | 1.0       | 41.09     | 6.0       | 6.0       | 0.0       |
# | 25        | -0.1089   | 11.0      | 6.0       | 8.559     | 6.0       | 6.0       | 0.0       |
# | 26        | -0.1333   | 11.0      | 1.0       | 13.22     | 6.0       | 6.0       | 0.0       |
# | 27        | -0.1232   | 14.0      | 6.0       | 30.88     | 1.0       | 6.0       | 0.0       |
# | 28        | -0.116    | 12.61     | 5.948     | 66.38     | 1.018     | 3.501     | 1.771     |
# | 29        | -0.135    | 11.2      | 2.591     | 43.33     | 5.993     | 1.322     | 4.177     |
# | 30        | -0.1337   | 12.6      | 3.365     | 2.156     | 3.893     | 4.148     | 3.792     |
# | 31        | -0.1178   | 14.0      | 6.0       | 10.47     | 1.0       | 6.0       | 0.0       |
# | 32        | -0.214    | 13.47     | 1.339     | 95.73     | 2.699     | 1.24      | 4.134     |
# | 33        | -0.1206   | 14.0      | 2.825     | 7.699     | 6.0       | 6.0       | 0.0       |
# | 34        | -0.1183   | 14.0      | 1.0       | 67.64     | 6.0       | 6.0       | 6.0       |
# | 35        | -0.1209   | 14.0      | 1.0       | 67.48     | 1.0       | 6.0       | 0.0       |
# | 36        | -0.1363   | 14.0      | 6.0       | 30.28     | 6.0       | 1.0       | 0.0       |
# | 37        | -0.1294   | 14.0      | 6.0       | 34.29     | 1.0       | 1.0       | 6.0       |
# | 38        | -0.1339   | 11.0      | 6.0       | 45.98     | 1.0       | 1.0       | 0.0       |
# | 39        | -0.1225   | 14.0      | 6.0       | 64.21     | 6.0       | 6.0       | 6.0       |
# | 40        | -0.1205   | 14.0      | 6.0       | 64.74     | 6.0       | 1.0       | 0.0       |
# | 41        | -0.1242   | 14.0      | 1.0       | 24.96     | 1.0       | 6.0       | 0.0       |
# | 42        | -0.1401   | 14.0      | 6.0       | 20.86     | 6.0       | 6.0       | 6.0       |
# | 43        | -0.1182   | 14.0      | 1.0       | 68.97     | 1.0       | 1.0       | 6.0       |
# | 44        | -0.1369   | 14.0      | 6.0       | 50.86     | 6.0       | 6.0       | 6.0       |
# | 45        | -0.1244   | 11.0      | 6.0       | 3.045     | 6.0       | 6.0       | 0.0       |
# | 46        | -0.1243   | 11.0      | 1.0       | 72.96     | 1.0       | 6.0       | 6.0       |
# | 47        | -0.1225   | 14.0      | 1.0       | 36.99     | 1.0       | 6.0       | 0.0       |
# | 48        | -0.1314   | 11.0      | 1.0       | 5.197     | 1.0       | 6.0       | 0.0       |
# | 49        | -0.1211   | 14.0      | 1.0       | 13.77     | 6.0       | 1.0       | 0.0       |
# | 50        | -0.116    | 11.0      | 1.0       | 67.61     | 6.0       | 1.0       | 6.0       |
# | 51        | -0.1225   | 14.0      | 1.0       | 62.95     | 6.0       | 1.0       | 6.0       |
# | 52        | -0.1177   | 14.0      | 6.0       | 61.49     | 1.0       | 1.0       | 0.0       |
# | 53        | -0.1195   | 11.0      | 6.0       | 67.84     | 1.0       | 6.0       | 6.0       |
# | 54        | -0.1179   | 11.52     | 5.31      | 61.85     | 1.674     | 5.558     | 0.0389    |
# | 55        | -0.1295   | 11.0      | 6.0       | 36.88     | 1.0       | 1.0       | 0.0       |
# =================================================================================================
# Bayesian Optimization took 31.50 seconds
#
# Optimized Input Parameters (Differential Evolution):
# [12.          3.80566203  4.35811306  3.          4.          3.        ]
# Predicted Output (Differential Evolution):
# [[ 1.4360169e-03  5.6929025e-04  8.5819614e-01 -1.0939165e+00]]
#
# Optimized Input Parameters (Particle Swarm Optimization):
# [12.          4.81894527 10.98102086  6.          3.          0.        ]
# Predicted Output (Particle Swarm Optimization):
# [[ 9.3383773e-04  5.8866874e-04  7.1554017e-01 -1.2629864e+00]]
#
# Optimized Input Parameters (Simulated Annealing):
# [12.          1.73759295 15.84172875  5.          1.          0.        ]
# Predicted Output (Simulated Annealing):
# [[ 9.4636343e-04  5.8122206e-04  7.0701474e-01 -1.2470055e+00]]
#
# Optimized Input Parameters (Shgo):
# [12.     4.75   0.053  4.     6.     3.   ]
# Predicted Output (Shgo):
# [[ 1.4642490e-03  5.6435878e-04  8.5954899e-01 -1.0779208e+00]]
#
# Optimized Input Parameters (Grid Search):
# [12, 1, 0.053, 1, 2, 3.0]
# Predicted Output (Grid Search):
# [[ 1.4601717e-03  5.7532173e-04  8.7714219e-01 -1.0975486e+00]]
#
# Optimized Input Parameters (Bayesian Optimization):
# [11.0, 1.0, 8.146453974319504, 6.0, 6.0, 0.0]
# Predicted Output (Bayesian Optimization):
# [[ 9.3243085e-04  5.8103580e-04  7.0180064e-01 -1.2504731e+00]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_absolute_error, mean_squared_error
import math

# Function to compute performance metrics
def compute_metrics(predictions, target):
    metrics = {}
    metrics['MAE'] = mean_absolute_error(target, predictions)
    metrics['MSE'] = mean_squared_error(target, predictions)
    metrics['RMSE'] = math.sqrt(metrics['MSE'])
    return metrics

# Compute metrics for all optimization results
metrics_dict = {}
for algo, (params, prediction) in optimized_results.items():
    metrics_dict[algo] = compute_metrics(prediction[0], target_output)

# Convert metrics to a DataFrame for easier plotting
import pandas as pd
metrics_df = pd.DataFrame(metrics_dict).T

# Plot the metrics
plt.figure(figsize=(12, 6))
metrics_df.plot(kind='bar', figsize=(12, 6))
plt.title('Performance Metrics for Different Optimization Algorithms')
plt.xlabel('Optimization Algorithm')
plt.ylabel('Metric Value')
plt.xticks(rotation=45)
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
# Compute and print metrics for all optimization results
for algo, (params, prediction) in optimized_results.items():
    metrics = compute_metrics(prediction[0], target_output)
    print(f"\nPerformance Metrics ({algo}):")
    print(f"MAE: {metrics['MAE']:.6f}")
    print(f"MSE: {metrics['MSE']:.6f}")
    print(f"RMSE: {metrics['RMSE']:.6f}")

# Plot the metrics as bar plots
plt.figure(figsize=(12, 6))
metrics_df.plot(kind='bar', figsize=(12, 6))
plt.title('Performance Metrics for Different Optimization Algorithms')
plt.xlabel('Optimization Algorithm')
plt.ylabel('Metric Value')
plt.xticks(rotation=45)
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()
# Out:
# Performance Metrics (Differential Evolution):
# MAE: 0.106658
# MSE: 0.041315
# RMSE: 0.203260
#
# Performance Metrics (Particle Swarm Optimization):
# MAE: 0.099933
# MSE: 0.020561
# RMSE: 0.143392
#
# Performance Metrics (Simulated Annealing):
# MAE: 0.106061
# MSE: 0.023226
# RMSE: 0.152399
#
# Performance Metrics (Shgo):
# MAE: 0.110324
# MSE: 0.044614
# RMSE: 0.211221
#
# Performance Metrics (Grid Search):
# MAE: 0.101092
# MSE: 0.040492
# RMSE: 0.201227
#
# Performance Metrics (Bayesian Optimization):
# MAE: 0.106494
# MSE: 0.023240
# RMSE: 0.152446

# %%
# import tensorflow as tf
# from tensorflow.keras import layers, models
# import numpy as np

# # Sample data
# x_data = np.array([
#     [6, 0.053, 1, 2, 6],
#     [1, 100.0, 3, 4, 0]
# ])
# y_data = np.array([
#     [7e-6, 8.804207e-9, 2.0, -1.68],
#     [0.005373, 3.050072e-8, 1.75, -1.0]
# ])

# # Define the generator model
# def build_generator(output_dim):
#     model = models.Sequential([
#         layers.Dense(256, activation='relu', input_shape=(100,)),
#         layers.BatchNormalization(),
#         layers.Dense(128, activation='relu'),
#         layers.Dense(output_dim, activation='linear')
#     ])
#     return model

# # Define the discriminator model
# def build_discriminator(input_dim):
#     model = models.Sequential([
#         layers.Dense(256, activation='relu', input_shape=(input_dim,)),
#         layers.BatchNormalization(),
#         layers.Dense(128, activation='relu'),
#         layers.Dense(1, activation='linear')
#     ])
#     return model


# # Compile the GAN
# def build_gan(generator, discriminator):
#     discriminator.compile(optimizer='adam', loss='binary_crossentropy')
#     discriminator.trainable = False
#     gan_input = layers.Input(shape=(100,))
#     generated_input = generator(gan_input)
#     combined_input = layers.Concatenate()([gan_input, generated_input])
#     gan_output = discriminator(combined_input)
#     gan = models.Model(gan_input, gan_output)
#     gan.compile(optimizer='adam', loss='binary_crossentropy')
#     return gan

# # Custom rounding function
# def round_params(generated_params):
#     generated_params[:, :2] = np.round(generated_params[:, :2])
#     generated_params[:, 3:] = np.round(generated_params[:, 3:])
#     return generated_params

# # Build and compile the models
# generator = build_generator(output_dim=x_data.shape[1])
# discriminator_input_dim = x_data.shape[1] + y_data.shape[1]
# discriminator = build_discriminator(input_dim=discriminator_input_dim)

# gan = build_gan(generator, discriminator)

# # Training the GAN
# epochs = 10000
# batch_size = 2

# for epoch in range(epochs):
#     # Train the discriminator
#     idx = np.random.randint(0, x_data.shape[0], batch_size)
#     real_inputs = x_data[idx]
#     real_outputs = y_data[idx]
#     noise = np.random.normal(0, 1, (batch_size, 100))
#     generated_inputs = generator.predict(noise)
#     generated_inputs = round_params(generated_inputs)
#     real_pairs = np.concatenate([real_inputs, real_outputs], axis=1)
#     generated_pairs = np.concatenate([noise, generated_inputs], axis=1)

#     d_loss_real = discriminator.train_on_batch(real_pairs, np.ones((batch_size, 1)))
#     d_loss_fake = discriminator.train_on_batch(generated_pairs, np.zeros((batch_size, 1)))
#     d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

#     # Train the generator
#     noise = np.random.normal(0, 1, (batch_size, 100))
#     g_loss = gan.train_on_batch(noise, np.ones((batch_size, 1)))

#     if epoch % 1000 == 0:
#         print(f"{epoch} [D loss: {d_loss}] [G loss: {g_loss}]")

# # Inverse design: generate input parameters given a desired output
# desired_output = np.array([[0.001, 1e-08, 2.0, -1.5]])  # Example desired output
# noise = np.random.normal(0, 1, (1, 100))
# generated_input = generator.predict(noise)
# generated_input = round_params(generated_input)
# print("Generated input parameters for desired output:", generated_input)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-b822930f98ef> in <cell line: 59>()
#      57 discriminator = build_discriminator(input_dim=discriminator_input_dim)
#      58
# ---> 59 gan = build_gan(generator, discriminator)
#      60
#      61 # Training the GAN
#
# <ipython-input-53-b822930f98ef> in build_gan(generator, discriminator)
#      41     generated_input = generator(gan_input)
#      42     combined_input = layers.Concatenate()([gan_input, generated_input])
# ---> 43     gan_output = discriminator(combined_input)
#      44     gan = models.Model(gan_input, gan_output)
#      45     gan.compile(optimizer='adam', loss='binary_crossentropy')
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     278                     None,
#     279                 }:
# --> 280                     raise ValueError(
#     281                         f'Input {input_index} of layer "{layer_name}" is '
#     282                         f"incompatible with the layer: expected axis {axis} "
#
# ValueError: Exception encountered when calling layer "sequential_28" (type Sequential).
#
# Input 0 of layer "dense_165" is incompatible with the layer: expected axis -1 of input shape to have value 9, but received input with shape (None, 105)
#
# Call arguments received by layer "sequential_28" (type Sequential):
#   • inputs=tf.Tensor(shape=(None, 105), dtype=float32)
#   • training=None
#   • mask=None

# %%
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np

# Generator Model
def build_generator(input_dim, output_dim):
    model = tf.keras.Sequential([
        layers.Dense(128, activation='relu', input_dim=input_dim),
        layers.Dense(256, activation='relu'),
        layers.Dense(512, activation='relu'),
        layers.Dense(output_dim, activation='linear')
    ])
    return model

# Discriminator Model
def build_discriminator(input_dim):
    model = tf.keras.Sequential([
        layers.Dense(512, activation='leaky_relu', input_dim=input_dim),
        layers.Dense(256, activation='leaky_relu'),
        layers.Dense(1, activation='linear')
    ])
    return model

# Hyperparameters
z_dim = 100  # Dimension of the noise input to the generator
data_dim = 6  # Dimension of the data

# Initialize the models
generator = build_generator(z_dim, data_dim)
discriminator = build_discriminator(data_dim)

# Compile the discriminator
discriminator.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5), loss='mse')

# Build and compile the GAN model
discriminator.trainable = False

gan_input = layers.Input(shape=(z_dim,))
generated_data = generator(gan_input)
gan_output = discriminator(generated_data)

gan = tf.keras.models.Model(gan_input, gan_output)
gan.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5), loss='mse')

# %%
# Number of epochs
num_epochs = 100
batch_size = 64

# # Example dataset (update this with your actual data)
# x = np.array([
#     [11, 6, 0.053, 1, 2, 6],
#     [12, 1, 100.000, 3, 4, 0],
#     [13, 1, 100.000, 3, 5, 4],
#     [14, 3, 1.000, 6, 1, 0],
#     [14, 5, 1.000, 6, 1, 0],
#     [14, 7, 1.000, 6, 1, 0]
# ])

# Function to generate real data from your dataset
def get_real_data():
    return x

# Training loop
for epoch in range(num_epochs):
    # Train Discriminator
    real_data = get_real_data()
    batch_size_real = real_data.shape[0]

    labels_real = np.ones((batch_size_real, 1))
    labels_fake = np.zeros((batch_size_real, 1))

    d_loss_real = discriminator.train_on_batch(real_data, labels_real)

    z = np.random.normal(0, 1, (batch_size_real, z_dim))
    fake_data = generator.predict(z)

    d_loss_fake = discriminator.train_on_batch(fake_data, labels_fake)

    d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

    # Train Generator
    z = np.random.normal(0, 1, (batch_size, z_dim))
    labels_gan = np.ones((batch_size, 1))

    g_loss = gan.train_on_batch(z, labels_gan)

    if epoch % 10 == 0:
        print(f'Epoch [{epoch}/{num_epochs}], d_loss: {d_loss}, g_loss: {g_loss}')

print("Training completed.")
# Out:
# 1/1 [==============================] - 0s 65ms/step
# Epoch [0/1000], d_loss: 0.08519823162350804, g_loss: 0.9100799560546875
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# Epoch [100/1000], d_loss: 0.28886501491069794, g_loss: 0.9236549139022827
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# Epoch [200/1000], d_loss: 0.21085740998387337, g_loss: 0.7645223140716553
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Epoch [300/1000], d_loss: 0.2273121327161789, g_loss: 0.61153244972229
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 139ms/step
# Epoch [400/1000], d_loss: 0.2287823185324669, g_loss: 0.6133699417114258
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# Epoch [500/1000], d_loss: 0.2335568144917488, g_loss: 0.5387319326400757
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# Epoch [600/1000], d_loss: 0.23354681581258774, g_loss: 0.5981482863426208
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# Epoch [700/1000], d_loss: 0.22012733295559883, g_loss: 0.5190013647079468
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# Epoch [800/1000], d_loss: 0.19149081408977509, g_loss: 0.6077076196670532
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# Epoch [900/1000], d_loss: 0.18647871538996696, g_loss: 0.6246613264083862
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 37ms/step
# Training completed.

# %%
# Define bounds
bounds = {
    'param1': (11, 14),
    'param2': (1, 6),
    'param3': (0.053, 100.000),
    'param4': (1, 6),
    'param5': (1, 6),
    'param6': (0, 6)
}

# Function to post-process the generated samples
def post_process_samples(samples, bounds):
    samples[:, 0] = np.clip(np.round(samples[:, 0]), bounds['param1'][0], bounds['param1'][1])
    samples[:, 1] = np.clip(np.round(samples[:, 1]), bounds['param2'][0], bounds['param2'][1])
    samples[:, 2] = np.clip(samples[:, 2], bounds['param3'][0], bounds['param3'][1])
    samples[:, 3] = np.clip(np.round(samples[:, 3]), bounds['param4'][0], bounds['param4'][1])
    samples[:, 4] = np.clip(np.round(samples[:, 4]), bounds['param5'][0], bounds['param5'][1])
    samples[:, 5] = np.clip(np.round(samples[:, 5]), bounds['param6'][0], bounds['param6'][1])
    return samples

# Generate new samples
# z = np.random.normal(0, 1, (10, z_dim))  # Generate 10 new samples
z = np.array([0.1,0.2,0.3,0.4])
generated_samples = generator.predict(z)

# Post-process the generated samples
processed_samples = post_process_samples(generated_samples, bounds)

print("Generated Samples:")
print(processed_samples)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-45-2e9a592f5a8c> in <cell line: 24>()
#      22 # z = np.random.normal(0, 1, (10, z_dim))  # Generate 10 new samples
#      23 z = np.array([0.1,0.2,0.3,0.4])
# ---> 24 generated_samples = generator.predict(z)
#      25
#      26 # Post-process the generated samples
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node sequential_24/dense_91/MatMul defined at (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#
#   File "/usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#
#   File "/usr/local/lib/python3.10/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelapp.py", line 619, in start
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/platform/asyncio.py", line 195, in start
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 685, in <lambda>
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 738, in _run_callback
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 825, in inner
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 786, in run
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 361, in process_one
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 261, in dispatch_shell
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 539, in execute_request
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py", line 302, in do_execute
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 539, in run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#
#   File "<ipython-input-45-2e9a592f5a8c>", line 24, in <cell line: 24>
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2655, in predict
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2440, in predict_function
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2425, in step_function
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2413, in run_step
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2381, in predict_step
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 590, in __call__
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/sequential.py", line 398, in call
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/functional.py", line 515, in call
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/functional.py", line 672, in _run_internal_graph
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py", line 241, in call
#
# In[0] ndims must be >= 2: 1
# 	 [[{{node sequential_24/dense_91/MatMul}}]] [Op:__inference_predict_function_375542]

# %%
# INT
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np

# Custom activation layer for integer output
class IntegerActivation(layers.Layer):
    def call(self, inputs):
        return tf.round(inputs)

# Generator Model
def build_generator(input_dim, output_dim):
    input_layer = layers.Input(shape=(input_dim,))

    x = layers.Dense(128, activation='relu')(input_layer)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dense(512, activation='relu')(x)

    param1 = layers.Dense(1, activation='linear')(x)
    param2 = layers.Dense(1, activation='linear')(x)
    param3 = layers.Dense(1, activation='linear')(x)  # Float value, no activation change
    param4 = layers.Dense(1, activation='linear')(x)
    param5 = layers.Dense(1, activation='linear')(x)
    param6 = layers.Dense(1, activation='linear')(x)

    param1 = IntegerActivation()(param1)
    param2 = IntegerActivation()(param2)
    param4 = IntegerActivation()(param4)
    param5 = IntegerActivation()(param5)
    param6 = IntegerActivation()(param6)

    output_layer = layers.Concatenate()([param1, param2, param3, param4, param5, param6])

    model = tf.keras.models.Model(inputs=input_layer, outputs=output_layer)
    return model

# Discriminator Model
def build_discriminator(input_dim):
    model = tf.keras.Sequential([
        layers.Dense(512, activation='leaky_relu', input_dim=input_dim),
        layers.Dense(256, activation='leaky_relu'),
        layers.Dense(1, activation='linear')
    ])
    return model

# Hyperparameters
z_dim = 100  # Dimension of the noise input to the generator
data_dim = 6  # Dimension of the data

# Initialize the models
generator = build_generator(z_dim, data_dim)
discriminator = build_discriminator(data_dim)

# Compile the discriminator
discriminator.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5), loss='mse')

# Build and compile the GAN model
discriminator.trainable = False

gan_input = layers.Input(shape=(z_dim,))
generated_data = generator(gan_input)
gan_output = discriminator(generated_data)

gan = tf.keras.models.Model(gan_input, gan_output)
gan.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5), loss='mse')

# %%
# Number of epochs
num_epochs = 100
batch_size = 64


# Normalize the float column (param3) for better performance
x[:, 2] = (x[:, 2] - 0.053) / (100.000 - 0.053)

# Function to generate real data from your dataset
def get_real_data():
    return x

# Training loop
for epoch in range(num_epochs):
    # Train Discriminator
    real_data = get_real_data()
    batch_size_real = real_data.shape[0]

    labels_real = np.ones((batch_size_real, 1))
    labels_fake = np.zeros((batch_size_real, 1))

    d_loss_real = discriminator.train_on_batch(real_data, labels_real)

    z = np.random.normal(0, 1, (batch_size_real, z_dim))
    fake_data = generator.predict(z)

    d_loss_fake = discriminator.train_on_batch(fake_data, labels_fake)

    d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

    # Train Generator
    z = np.random.normal(0, 1, (batch_size, z_dim))
    labels_gan = np.ones((batch_size, 1))

    g_loss = gan.train_on_batch(z, labels_gan)

    if epoch % 10 == 0:
        print(f'Epoch [{epoch}/{num_epochs}], d_loss: {d_loss}, g_loss: {g_loss}')

print("Training completed.")
# Out:
# 1/1 [==============================] - 0s 211ms/step
# WARNING:tensorflow:Gradients do not exist for variables ['dense_22/kernel:0', 'dense_22/bias:0', 'dense_23/kernel:0', 'dense_23/bias:0', 'dense_25/kernel:0', 'dense_25/bias:0', 'dense_26/kernel:0', 'dense_26/bias:0', 'dense_27/kernel:0', 'dense_27/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_22/kernel:0', 'dense_22/bias:0', 'dense_23/kernel:0', 'dense_23/bias:0', 'dense_25/kernel:0', 'dense_25/bias:0', 'dense_26/kernel:0', 'dense_26/bias:0', 'dense_27/kernel:0', 'dense_27/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_22/kernel:0', 'dense_22/bias:0', 'dense_23/kernel:0', 'dense_23/bias:0', 'dense_25/kernel:0', 'dense_25/bias:0', 'dense_26/kernel:0', 'dense_26/bias:0', 'dense_27/kernel:0', 'dense_27/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_22/kernel:0', 'dense_22/bias:0', 'dense_23/kernel:0', 'dense_23/bias:0', 'dense_25/kernel:0', 'dense_25/bias:0', 'dense_26/kernel:0', 'dense_26/bias:0', 'dense_27/kernel:0', 'dense_27/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# Epoch [0/100], d_loss: 0.1506273306440562, g_loss: 0.9611825942993164
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# Training completed.

# %%
# Define bounds
bounds = {
    'param1': (11, 14),
    'param2': (1, 6),
    'param3': (0.053, 100.000),
    'param4': (1, 6),
    'param5': (1, 6),
    'param6': (0, 6)
}

# Function to post-process the generated samples
def post_process_samples(samples, bounds):
    samples[:, 0] = np.clip(samples[:, 0], bounds['param1'][0], bounds['param1'][1])
    samples[:, 1] = np.clip(samples[:, 1], bounds['param2'][0], bounds['param2'][1])
    samples[:, 2] = samples[:, 2] * (bounds['param3'][1] - bounds['param3'][0]) + bounds['param3'][0]  # Denormalize
    samples[:, 3] = np.clip(samples[:, 3], bounds['param4'][0], bounds['param4'][1])
    samples[:, 4] = np.clip(samples[:, 4], bounds['param5'][0], bounds['param5'][1])
    samples[:, 5] = np.clip(samples[:, 5], bounds['param6'][0], bounds['param6'][1])
    return samples

# Generate new samples
z = np.random.normal(0, 1, (10, z_dim))  # Generate 10 new samples
generated_samples = generator.predict(z)

# Post-process the generated samples
processed_samples = post_process_samples(generated_samples, bounds)

print("Generated Samples:")
print(processed_samples)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# Generated Samples:
# [[11.        1.       42.28343   1.        1.        0.      ]
#  [11.        1.       20.684832  1.        1.        0.      ]
#  [11.        1.       26.448273  1.        1.        0.      ]
#  [11.        1.       18.103437  1.        1.        0.      ]
#  [11.        1.       50.125523  1.        1.        0.      ]
#  [11.        1.       46.149002  1.        1.        0.      ]
#  [11.        1.       17.235891  1.        1.        0.      ]
#  [11.        1.       24.77718   1.        1.        0.      ]
#  [11.        1.       36.967644  1.        1.        0.      ]
#  [11.        1.       70.83195   1.        1.        0.      ]]

# %%
x
# Out:
#    mname  mthickness (nm)  cellarea (µm2)  topelectrode  bottomelectrode  \
# 0     11                6           0.053             1                2
# 1     12                1         100.000             3                4
# 2     13                1         100.000             3                5
# 3     14                3           1.000             6                1
# 4     14                5           1.000             6                1
# 5     14                7           1.000             6                1
#
#    extrastack
# 0           6
# 1           0
# 2           4
# 3           0
# 4           0
# 5           0

# %%
y
# Out:
#     roff_rv        ron_rv     vs    vr
# 0  0.000007  8.804207e-09  2.000 -1.68
# 1  0.005373  3.050072e-08  1.750 -1.00
# 2  0.000663  3.682850e-08  0.750 -0.75
# 3  0.000256  5.926848e-06  0.877 -1.50
# 4  0.000407  2.387368e-05  0.580 -1.50
# 5  0.000647  1.113548e-04  0.660 -1.50

# %%
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np

# Generator Model
def build_generator(input_dim, output_dim):
    model = tf.keras.Sequential([
        layers.Dense(128, activation='relu', input_dim=input_dim),
        layers.Dense(256, activation='relu'),
        layers.Dense(512, activation='relu'),
        layers.Dense(output_dim, activation='linear')
    ])
    return model

# Discriminator Model
def build_discriminator(input_dim):
    model = tf.keras.Sequential([
        layers.Dense(512, activation='leaky_relu', input_dim=input_dim),
        layers.Dense(256, activation='leaky_relu'),
        layers.Dense(1, activation='linear')
    ])
    return model

# Hyperparameters
z_dim = 100  # Dimension of the noise input to the generator
input_dim = 4  # Dimension of input parameters
output_dim = 6  # Dimension of output parameters

# Initialize the models
generator = build_generator(z_dim, output_dim)  # Note: input_dim is z_dim for the generator
discriminator = build_discriminator(output_dim)

# Compile the discriminator
discriminator.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5), loss='mse')

# Build and compile the GAN model
discriminator.trainable = False

# Define bounds for post-processing
bounds = {
    'param1': (11, 14),
    'param2': (1, 6),
    'param3': (0.053, 100.000),
    'param4': (1, 6),
    'param5': (1, 6),
    'param6': (0, 6)
}

# Function to post-process the generated samples
def post_process_samples(samples, bounds):
    samples[:, 0] = np.clip(np.round(samples[:, 0]), bounds['param1'][0], bounds['param1'][1])
    samples[:, 1] = np.clip(np.round(samples[:, 1]), bounds['param2'][0], bounds['param2'][1])
    samples[:, 2] = np.clip(samples[:, 2], bounds['param3'][0], bounds['param3'][1])
    samples[:, 3] = np.clip(np.round(samples[:, 3]), bounds['param4'][0], bounds['param4'][1])
    samples[:, 4] = np.clip(np.round(samples[:, 4]), bounds['param5'][0], bounds['param5'][1])
    samples[:, 5] = np.clip(np.round(samples[:, 5]), bounds['param6'][0], bounds['param6'][1])
    return samples

# Inverse design function
def inverse_design(generator, target_output, z_dim, learning_rate=0.001, steps=1000):
    # Initialize a latent vector
    z = tf.Variable(np.random.normal(0, 1, (1, z_dim)), dtype=tf.float32)

    # Define the optimizer
    optimizer = tf.keras.optimizers.Adam(learning_rate)

    # Define the loss function
    def loss_fn():
        generated_output = generator(z)
        return tf.reduce_mean(tf.square(generated_output - target_output))

    # Optimization loop
    for step in range(steps):
        optimizer.minimize(loss_fn, var_list=[z])
        if step % 100 == 0:
            loss_value = loss_fn().numpy()
            print(f'Step {step}, Loss: {loss_value}')

    # Get the optimized latent vector and generated output
    optimized_z = z.numpy()
    generated_output = generator(optimized_z).numpy()
    return optimized_z, generated_output

# Example target output (adjust as needed)
target_output = np.array([[ 11, 6, 0.053, 1, 2, 6]])

# Perform inverse design
optimized_z, generated_output = inverse_design(generator, target_output, z_dim)

# Post-process the generated output
processed_output = post_process_samples(generated_output, bounds)

print("Target Output:")
print(target_output)
print("Generated Output:")
print(processed_output)

# Save the GAN model
generator.save('saved_models/generator_model.h5')
discriminator.save('saved_models/discriminator_model.h5')

print("GAN models saved.")
# Out:
# Step 0, Loss: 32.25944900512695
# Step 100, Loss: 31.35838508605957
# Step 200, Loss: 30.6011905670166
# Step 300, Loss: 29.995622634887695
# Step 400, Loss: 29.460176467895508
# Step 500, Loss: 28.987661361694336
# Step 600, Loss: 28.55036735534668
# Step 700, Loss: 28.144819259643555
# Step 800, Loss: 27.70709228515625
# Step 900, Loss: 27.224390029907227
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Target Output:
# [[11.     6.     0.053  1.     2.     6.   ]]
# Generated Output:
# [[11.     1.     0.053  1.     1.     1.   ]]
# GAN models saved.
# Object `added` not found.

# %%
import tensorflow as tf
from tensorflow.keras import layers

# Generator Model (assuming z_dim is 100)
def build_generator(z_dim, output_dim):
    model = tf.keras.Sequential([
        layers.Dense(128, activation='relu', input_dim=z_dim),
        layers.Dense(256, activation='relu'),
        layers.Dense(512, activation='relu'),
        layers.Dense(output_dim, activation='linear')
    ])
    return model

# Load trained generator model
def load_generator_model():
    generator = build_generator(100, 6)  # Assuming z_dim is 100 and output_dim is 6
    generator.load_weights('saved_models/generator_model.h5')  # Adjust path to weights
    return generator

# Load trained generator model
generator = load_generator_model()

# Example input with 100-dimensional noise vector (adjust as per your requirements)
input_params = np.random.normal(0, 1, size=(1, 100))  # Adjust size as per your requirements

# Generate predictions
generated_output = generator.predict(input_params)

# Function to post-process the generated samples (assuming you have it from previous code)
def post_process_samples(samples, bounds):
    samples[:, 0] = np.clip(np.round(samples[:, 0]), bounds['param1'][0], bounds['param1'][1])
    samples[:, 1] = np.clip(np.round(samples[:, 1]), bounds['param2'][0], bounds['param2'][1])
    samples[:, 2] = np.clip(samples[:, 2], bounds['param3'][0], bounds['param3'][1])
    samples[:, 3] = np.clip(np.round(samples[:, 3]), bounds['param4'][0], bounds['param4'][1])
    samples[:, 4] = np.clip(np.round(samples[:, 4]), bounds['param5'][0], bounds['param5'][1])
    samples[:, 5] = np.clip(np.round(samples[:, 5]), bounds['param6'][0], bounds['param6'][1])
    return samples

# Example bounds for post-processing (adjust as per your requirements)
bounds = {
    'param1': (11, 14),
    'param2': (1, 6),
    'param3': (0.053, 100.000),
    'param4': (1, 6),
    'param5': (1, 6),
    'param6': (0, 6)
}

# Post-process the generated output
processed_output = post_process_samples(generated_output, bounds)

# Print generated output
print("Generated Output:")
print(processed_output)
# Out:
# 1/1 [==============================] - 0s 121ms/step
# Generated Output:
# [[11.        1.        0.271343  1.        1.        0.      ]]

# %%
import tensorflow as tf
import numpy as np

# Function to build your generator model (assuming you have it defined)
def build_generator(input_dim, output_dim):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(128, activation='relu', input_dim=input_dim),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(output_dim, activation='linear')
    ])
    return model

# Function to load your trained generator model
def load_generator_model():
    generator = build_generator(input_dim=4, output_dim=6)  # Adjust input_dim and output_dim as per your trained model
    generator.load_weights('/content/saved_models/generator_model.h5')  # Adjust path to weights
    return generator

# Load trained generator model
generator = load_generator_model()

# Example input with 4 parameters (you can modify this as needed)
input_params = np.array([0.1,0.2,0.3,0.4])  # Generates random input with 4 dimensions

# Generate predictions
generated_output = generator.predict(input_params)

# Print generated output
print("Generated Output:")
print(generated_output)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-d46faf5116a4> in <cell line: 27>()
#      25
#      26 # Generate predictions
# ---> 27 generated_output = generator.predict(input_params)
#      28
#      29 # Print generated output
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__predict_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2440, in predict_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2425, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2413, in run_step  **
#         outputs = model.predict_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2381, in predict_step
#         return self(x, training=False)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/input_spec.py", line 253, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Exception encountered when calling layer 'sequential_25' (type Sequential).
#
#     Input 0 of layer "dense_95" is incompatible with the layer: expected min_ndim=2, found ndim=1. Full shape received: (None,)
#
#     Call arguments received by layer 'sequential_25' (type Sequential):
#       • inputs=tf.Tensor(shape=(None,), dtype=float32)
#       • training=False
#       • mask=None

# %%
import tensorflow as tf
import numpy as np

# Generator Model
def build_generator(input_dim, output_dim):
    model = tf.keras.Sequential([
        layers.Dense(128, activation='relu', input_dim=input_dim),
        layers.Dense(256, activation='relu'),
        layers.Dense(512, activation='relu'),
        layers.Dense(output_dim, activation='linear')
    ])
    return model

# Discriminator Model
def build_discriminator(input_dim):
    model = tf.keras.Sequential([
        layers.Dense(512, activation='leaky_relu', input_dim=input_dim),
        layers.Dense(256, activation='leaky_relu'),
        layers.Dense(1, activation='linear')
    ])
    return model

# Hyperparameters
input_dim = 4  # Dimension of input parameters
output_dim = 6  # Dimension of output parameters

# Initialize the models
generator = build_generator(input_dim, output_dim)
discriminator = build_discriminator(output_dim)

# Compile the discriminator
discriminator.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5), loss='mse')

# Build and compile the GAN model
discriminator.trainable = False

# Define bounds for post-processing
bounds = {
    'param1': (11, 14),
    'param2': (1, 6),
    'param3': (0.053, 100.000),
    'param4': (1, 6),
    'param5': (1, 6),
    'param6': (0, 6)
}

# Function to post-process the generated samples
def post_process_samples(samples, bounds):
    samples[:, 0] = np.clip(np.round(samples[:, 0]), bounds['param1'][0], bounds['param1'][1])
    samples[:, 1] = np.clip(np.round(samples[:, 1]), bounds['param2'][0], bounds['param2'][1])
    samples[:, 2] = np.clip(samples[:, 2], bounds['param3'][0], bounds['param3'][1])
    samples[:, 3] = np.clip(np.round(samples[:, 3]), bounds['param4'][0], bounds['param4'][1])
    samples[:, 4] = np.clip(np.round(samples[:, 4]), bounds['param5'][0], bounds['param5'][1])
    samples[:, 5] = np.clip(np.round(samples[:, 5]), bounds['param6'][0], bounds['param6'][1])
    return samples

# Inverse design function
def inverse_design(generator, target_output, input_dim, learning_rate=0.001, steps=1000):
    # Initialize a latent vector
    z = tf.Variable(np.random.normal(0, 1, (1, input_dim)), dtype=tf.float32)

    # Define the optimizer
    optimizer = tf.keras.optimizers.Adam(learning_rate)

    # Define the loss function
    def loss_fn():
        generated_output = generator(z)
        return tf.reduce_mean(tf.square(generated_output - target_output))

    # Optimization loop
    for step in range(steps):
        optimizer.minimize(loss_fn, var_list=[z])
        if step % 100 == 0:
            loss_value = loss_fn().numpy()
            print(f'Step {step}, Loss: {loss_value}')

    # Get the optimized latent vector and generated output
    optimized_z = z.numpy()
    generated_output = generator(optimized_z).numpy()
    return optimized_z, generated_output

# Example target output (adjust as needed)
target_output = np.array([[ 11, 6, 0.053, 1, 2, 6]])

# Perform inverse design
optimized_z, generated_output = inverse_design(generator, target_output, input_dim)

# Post-process the generated output
processed_output = post_process_samples(generated_output, bounds)

print("Target Output:")
print(target_output)
print("Generated Output:")
print(processed_output)

# Save the GAN model
generator.save('saved_models/generator_model.h5')
discriminator.save('saved_models/discriminator_model.h5')

print("GAN models saved.")
# Out:
# Step 0, Loss: 33.94606018066406
# Step 100, Loss: 33.870723724365234
# Step 200, Loss: 33.79981231689453
# Step 300, Loss: 33.73267364501953
# Step 400, Loss: 33.66493606567383
# Step 500, Loss: 33.612464904785156
# Step 600, Loss: 33.5617561340332
# Step 700, Loss: 33.512210845947266
# Step 800, Loss: 33.46010971069336
# Step 900, Loss: 33.4111328125
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Target Output:
# [[11.     6.     0.053  1.     2.     6.   ]]
# Generated Output:
# [[11.     1.     0.053  1.     1.     0.   ]]
# GAN models saved.

# %%
# Function to load your trained generator model
def load_generator_model():
    generator = build_generator(input_dim=4, output_dim=6)  # Adjust input_dim and output_dim as per your trained model
    generator.load_weights('/content/saved_models/generator_model.h5')  # Adjust path to weights
    return generator

# Load trained generator model
generator = load_generator_model()

# Example input with 4 parameters
input_params = np.array([[0.1, 0.1, 0.6, 0.1]])  # Generates random input with 4 dimensions

# Generate predictions
generated_output = generator.predict(input_params)

# Print generated output
print("Generated Output:")
print(generated_output)
# Out:
# 1/1 [==============================] - 0s 63ms/step
# Generated Output:
# [[-0.01115728 -0.03490774 -0.02685214  0.0131126  -0.01353251 -0.03837894]]

# %%
# Generator Model
def build_generator(input_dim, output_dim):
    model = tf.keras.Sequential([
        layers.Dense(128, activation='relu', input_dim=input_dim),
        layers.Dense(256, activation='relu'),
        layers.Dense(512, activation='relu'),
        layers.Dense(output_dim, activation='linear')
    ])
    return model

# Discriminator Model
def build_discriminator(input_dim):
    model = tf.keras.Sequential([
        layers.Dense(512, activation=tf.keras.layers.LeakyReLU(alpha=0.2), input_dim=input_dim),
        layers.Dense(256, activation=tf.keras.layers.LeakyReLU(alpha=0.2)),
        layers.Dense(1, activation='sigmoid')
    ])
    return model

# Hyperparameters
z_dim = y.shape[1]  # Dimension of the noise input to the generator, same as output y
output_dim = x.shape[1]  # Dimension of output parameters, same as input x

# Initialize the models
generator = build_generator(z_dim, output_dim)
discriminator = build_discriminator(output_dim + z_dim)

# Compile the discriminator
discriminator.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5), loss='binary_crossentropy', metrics=['accuracy'])

# Build and compile the GAN model
discriminator.trainable = False
gan_input = layers.Input(shape=(z_dim,))
generated_output = generator(gan_input)
gan_output = discriminator(tf.concat([generated_output, gan_input], axis=1))
gan = tf.keras.models.Model(gan_input, gan_output)
gan.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5), loss='binary_crossentropy')

# %%
# Training parameters
epochs = 100
batch_size = 32
sample_interval = 10

# Adversarial ground truths
valid = np.ones((batch_size, 1))
fake = np.zeros((batch_size, 1))

for epoch in range(epochs):
    # ---------------------
    #  Train Discriminator
    # ---------------------
    # Select a random half batch of real samples
    idx = np.random.randint(0, x.shape[0], batch_size)
    real_x = x[idx]
    real_y = y[idx]

    # Generate a half batch of new samples
    noise = np.random.normal(0, 1, (batch_size, z_dim))
    gen_x = generator.predict(noise)

    # Train the discriminator (real classified as ones and fake as zeros)
    d_loss_real = discriminator.train_on_batch(np.hstack((real_x, real_y)), valid)
    d_loss_fake = discriminator.train_on_batch(np.hstack((gen_x, noise)), fake)
    d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

    # ---------------------
    #  Train Generator
    # ---------------------
    # Train the generator (wants discriminator to mistake gen samples as real)
    g_loss = gan.train_on_batch(noise, valid)

    # If at save interval, print the progress
    if epoch % sample_interval == 0:
        print(f"{epoch} [D loss: {d_loss[0]}, acc.: {100*d_loss[1]}] [G loss: {g_loss}]")
# Out:
# 1/1 [==============================] - 0s 36ms/step
# 0 [D loss: 0.3697982244193554, acc.: 85.9375] [G loss: 0.8215440511703491]
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 10 [D loss: 0.4134671986103058, acc.: 89.0625] [G loss: 1.0388182401657104]
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 20 [D loss: 0.34167711436748505, acc.: 87.5] [G loss: 1.309492588043213]
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 30 [D loss: 0.36643774062395096, acc.: 89.0625] [G loss: 1.3292282819747925]
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 40 [D loss: 0.3195032700896263, acc.: 89.0625] [G loss: 1.5444884300231934]
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 50 [D loss: 0.2703106701374054, acc.: 89.0625] [G loss: 1.7666916847229004]
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 60 [D loss: 0.32426895946264267, acc.: 89.0625] [G loss: 1.3413915634155273]
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 70 [D loss: 0.31328219547867775, acc.: 87.5] [G loss: 1.3028345108032227]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 80 [D loss: 0.26208077371120453, acc.: 87.5] [G loss: 1.253551721572876]
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 90 [D loss: 0.2266897577792406, acc.: 95.3125] [G loss: 1.5463407039642334]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step

# %%
# Save the GAN model
generator.save('saved_models/generator_model.h5')
discriminator.save('saved_models/discriminator_model.h5')

print("GAN models saved.")

# Function to load your trained generator model
def load_generator_model():
    generator = build_generator(input_dim=z_dim, output_dim=output_dim)
    generator.load_weights('saved_models/generator_model.h5')  # Adjust path to weights
    return generator

# Load trained generator model
generator = load_generator_model()

# Example input with 4 parameters (from y)
input_params = np.array([[0.1, 0.2, 0.3, 0.4]])

# Generate predictions
generated_output = generator.predict(input_params)

# Print generated output
print("Generated Output:")
print(generated_output)
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# GAN models saved.
# 1/1 [==============================] - 0s 63ms/step
# Generated Output:
# [[-0.242904   -0.09871022  1.7885739  -0.36648172  0.01445589]]

# %%
y
# Out:
# array([[ 7.18116144e-06,  8.80420742e-09,  2.00000000e+00,
#         -1.68000000e+00],
#        [ 5.37337589e-03,  3.05007199e-08,  1.75000000e+00,
#         -1.00000000e+00],
#        [ 6.62965036e-04,  3.68284999e-08,  7.50000000e-01,
#         -7.50000000e-01],
#        [ 2.55648537e-04,  5.92684786e-06,  8.77000000e-01,
#         -1.50000000e+00],
#        [ 4.06763360e-04,  2.38736774e-05,  5.80000000e-01,
#         -1.50000000e+00],
#        [ 6.47202729e-04,  1.11354848e-04,  6.60000000e-01,
#         -1.50000000e+00]])

# %%
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np
import pandas as pd

# Assuming your x and y are in pandas DataFrame format
# x = x.values

# y = y.values

# # Normalize data if needed
# x = (x - x.min()) / (x.max() - x.min())
# y = (y - y.min()) / (y.max() - y.min())

x = x.values
y = y.values

# Generator Model
def build_generator(input_dim, output_dim):
    model = tf.keras.Sequential([
        layers.Dense(64, activation='relu', input_dim=input_dim),
        layers.BatchNormalization(),
        layers.Dropout(0.3),
        layers.Dense(128, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.3),
        layers.Dense(256, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.3),
        layers.Dense(256, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.3),
        layers.Dense(512, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.3),
        layers.Dense(output_dim, activation='linear')
    ])
    return model

# Discriminator Model
def build_discriminator(input_dim):
    model = tf.keras.Sequential([
        layers.Dense(1024, activation=tf.keras.layers.LeakyReLU(alpha=0.2), input_dim=input_dim),
        layers.Dropout(0.3),

        layers.Dense(512, activation=tf.keras.layers.LeakyReLU(alpha=0.2)),
        layers.Dropout(0.3),

        layers.Dense(256, activation=tf.keras.layers.LeakyReLU(alpha=0.2)),
        layers.Dropout(0.3),

        layers.Dense(128, activation=tf.keras.layers.LeakyReLU(alpha=0.2)),
        layers.Dropout(0.3),

        layers.Dense(64, activation=tf.keras.layers.LeakyReLU(alpha=0.2)),
        layers.Dense(1, activation='sigmoid')
    ])
    return model

# Hyperparameters
z_dim = y.shape[1]  # Dimension of the noise input to the generator, same as output y
output_dim = x.shape[1]  # Dimension of output parameters, same as input x

# Initialize the models
generator = build_generator(z_dim, output_dim)
discriminator = build_discriminator(output_dim + z_dim)

# Compile the discriminator
discriminator.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5), loss='binary_crossentropy', metrics=['accuracy'])

# Build and compile the GAN model
discriminator.trainable = False
gan_input = layers.Input(shape=(z_dim,))
generated_output = generator(gan_input)
gan_output = discriminator(tf.concat([generated_output, gan_input], axis=1))
gan = tf.keras.models.Model(gan_input, gan_output)
gan.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5), loss='binary_crossentropy')

# Training parameters
epochs = 1000
batch_size = 32
sample_interval = 100

# Adversarial ground truths
valid = np.ones((batch_size, 1))
fake = np.zeros((batch_size, 1))

for epoch in range(epochs):

    # Select a random half batch of real samples
    idx = np.random.randint(0, x.shape[0], batch_size)
    real_x = x[idx]
    real_y = y[idx]

    # Generate a half batch of new samples
    noise = np.random.normal(0, 1, (batch_size, z_dim))
    gen_x = generator.predict(noise)

    # Train the discriminator (real classified as ones and fake as zeros)
    d_loss_real = discriminator.train_on_batch(np.hstack((real_x, real_y)), valid)
    d_loss_fake = discriminator.train_on_batch(np.hstack((gen_x, noise)), fake)
    d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

    # Train the generator (wants discriminator to mistake gen samples as real)
    g_loss = gan.train_on_batch(noise, valid)

    # If at save interval, print the progress
    if epoch % sample_interval == 0:
        print(f"{epoch} [D loss: {d_loss[0]}, acc.: {100*d_loss[1]}] [G loss: {g_loss}]")

# Save the GAN model
generator.save('saved_models/generator_model.h5')
discriminator.save('saved_models/discriminator_model.h5')

print("GAN models saved.")
# Out:
# Streaming output truncated to the last 5000 lines.
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# ...
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# GAN models saved.

# %%
# Function to load your trained generator model
def load_generator_model():
    generator = build_generator(input_dim=z_dim, output_dim=output_dim)
    generator.load_weights('saved_models/generator_model.h5')  # Adjust path to weights
    return generator

# Load trained generator model
generator = load_generator_model()

# Example input with 4 parameters (from y)
input_params = np.array([[0.1, 0.2, 0.3, 0.4]])

# Generate predictions
generated_output = generator.predict(input_params)

# Print generated output
print("Generated Output:")
print(generated_output)
# Out:
# 1/1 [==============================] - 0s 309ms/step
# Generated Output:
# [[10.39163    0.8351954 80.212585   2.2949417  3.7131643  2.9914634]]

# %%
# INTEGER
# Function to load your trained generator model
def load_generator_model():
    generator = build_generator(input_dim=z_dim, output_dim=output_dim)
    generator.load_weights('/content/saved_models/generator_model.h5')  # Adjust path to weights
    return generator

# Load trained generator model
generator = load_generator_model()

# Define bounds for post-processing
bounds = {
    'param1': (11, 14),
    'param2': (1, 6),
    'param3': (0.053, 100.000),
    'param4': (1, 6),
    'param5': (1, 6),
    'param6': (0, 6)
}

# Example input with 4 parameters (from y)
input_params = np.array([[0.1, 0.2, 0.3, 0.4]])

# Generate predictions
generated_output = generator.predict(input_params)

# Function to post-process the generated samples
def post_process_samples(samples, bounds):
    processed_samples = np.zeros_like(samples)
    processed_samples[:, 0] = np.clip(np.round(samples[:, 0]), bounds['param1'][0], bounds['param1'][1])
    processed_samples[:, 1] = np.clip(np.round(samples[:, 1]), bounds['param2'][0], bounds['param2'][1])
    processed_samples[:, 2] = np.clip(samples[:, 2], bounds['param3'][0], bounds['param3'][1])
    processed_samples[:, 3] = np.clip(np.round(samples[:, 3]), bounds['param4'][0], bounds['param4'][1])
    processed_samples[:, 4] = np.clip(np.round(samples[:, 4]), bounds['param5'][0], bounds['param5'][1])
    processed_samples[:, 5] = np.clip(np.round(samples[:, 5]), bounds['param6'][0], bounds['param6'][1])
    return processed_samples

# Post-process the generated output
processed_output = post_process_samples(generated_output, bounds)

# Print generated output
print("Generated Output:")
print(processed_output)
# Out:
# 1/1 [==============================] - 0s 247ms/step
# Generated Output:
# [[11.        1.       80.212585  2.        4.        3.      ]]

# %%
gan.summary()
discriminator.summary()
generator.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 4)]                  0         []
#
#  sequential_12 (Sequential)  (None, 6)                    246982    ['input_4[0][0]']
#
#  tf.concat_2 (TFOpLambda)    (None, 10)                   0         ['sequential_12[0][0]',
#                                                                      'input_4[0][0]']
#
#  sequential_13 (Sequential)  (None, 1)                    708609    ['tf.concat_2[0][0]']
#
# ==================================================================================================
# Total params: 955591 (3.65 MB)
# Trainable params: 244550 (955.27 KB)
# Non-trainable params: 711041 (2.71 MB)
# __________________________________________________________________________________________________
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_81 (Dense)            (None, 1024)              11264
#
#  dropout_16 (Dropout)        (None, 1024)              0
#
#  dense_82 (Dense)            (None, 512)               524800
#
#  dropout_17 (Dropout)        (None, 512)               0
#
#  dense_83 (Dense)            (None, 256)               131328
#
#  dropout_18 (Dropout)        (None, 256)               0
#
#  dense_84 (Dense)            (None, 128)               32896
#
#  dropout_19 (Dropout)        (None, 128)               0
#
#  dense_85 (Dense)            (None, 64)                8256
#
#  dense_86 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 708609 (2.70 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 708609 (2.70 MB)
# _________________________________________________________________
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_93 (Dense)            (None, 64)                320
#
#  batch_normalization_16 (Ba  (None, 64)                256
#  tchNormalization)
#
#  dropout_25 (Dropout)        (None, 64)                0
#
#  dense_94 (Dense)            (None, 128)               8320
#
#  batch_normalization_17 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dropout_26 (Dropout)        (None, 128)               0
#
#  dense_95 (Dense)            (None, 256)               33024
#
#  batch_normalization_18 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_27 (Dropout)        (None, 256)               0
#
#  dense_96 (Dense)            (None, 256)               65792
#
#  batch_normalization_19 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_28 (Dropout)        (None, 256)               0
#
#  dense_97 (Dense)            (None, 512)               131584
#
#  batch_normalization_20 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dropout_29 (Dropout)        (None, 512)               0
#
#  dense_98 (Dense)            (None, 6)                 3078
#
# =================================================================
# Total params: 246982 (964.77 KB)
# Trainable params: 244550 (955.27 KB)
# Non-trainable params: 2432 (9.50 KB)
# _________________________________________________________________

# %%
# Generate predictions for evaluation
noise = np.random.normal(0, 1, (x.shape[0], z_dim))
generated_output = generator.predict(noise)
processed_output = post_process_samples(generated_output, bounds)

# Evaluate the performance metrics
def compute_metrics(true_data, predicted_data):
    metrics = {}
    metrics['MAE'] = mean_absolute_error(true_data, predicted_data)
    metrics['MSE'] = mean_squared_error(true_data, predicted_data)
    metrics['RMSE'] = math.sqrt(metrics['MSE'])
    return metrics

metrics = compute_metrics(x, processed_output)
print("Performance Metrics:")
print(f"MAE: {metrics['MAE']:.6f}")
print(f"MSE: {metrics['MSE']:.6f}")
print(f"RMSE: {metrics['RMSE']:.6f}")
# Out:
# 1/1 [==============================] - 0s 28ms/step
# Performance Metrics:
# MAE: 13.359639
# MSE: 1104.233411
# RMSE: 33.230008

# %%
from visualkeras import layered_view

# Visualize the generator model
layered_view(generator, legend=True, draw_volume=False).show()

# Visualize the discriminator model
layered_view(discriminator, legend=True, draw_volume=False).show()

# Visualize the GAN model
layered_view(gan, legend=True, draw_volume=False).show()

# %%
visualkeras.layered_view(discriminator , legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=556x63>

# %%
x
# Out:
# array([[1.1e+01, 6.0e+00, 5.3e-02, 1.0e+00, 2.0e+00, 6.0e+00],
#        [1.2e+01, 1.0e+00, 1.0e+02, 3.0e+00, 4.0e+00, 0.0e+00],
#        [1.3e+01, 1.0e+00, 1.0e+02, 3.0e+00, 5.0e+00, 4.0e+00],
#        [1.4e+01, 3.0e+00, 1.0e+00, 6.0e+00, 1.0e+00, 0.0e+00],
#        [1.4e+01, 5.0e+00, 1.0e+00, 6.0e+00, 1.0e+00, 0.0e+00],
#        [1.4e+01, 7.0e+00, 1.0e+00, 6.0e+00, 1.0e+00, 0.0e+00]])

# %%
y
# Out:
# array([[ 7.18116144e-06,  8.80420742e-09,  2.00000000e+00,
#         -1.68000000e+00],
#        [ 5.37337589e-03,  3.05007199e-08,  1.75000000e+00,
#         -1.00000000e+00],
#        [ 6.62965036e-04,  3.68284999e-08,  7.50000000e-01,
#         -7.50000000e-01],
#        [ 2.55648537e-04,  5.92684786e-06,  8.77000000e-01,
#         -1.50000000e+00],
#        [ 4.06763360e-04,  2.38736774e-05,  5.80000000e-01,
#         -1.50000000e+00],
#        [ 6.47202729e-04,  1.11354848e-04,  6.60000000e-01,
#         -1.50000000e+00]])
