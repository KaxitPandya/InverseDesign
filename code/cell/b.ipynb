# %%
# Set up lattice
# vector_a = [2.8837582303740374, 0.0, 0.0]*Angstrom
# vector_b = [0.0, 2.8837582303740374, 0.0]*Angstrom
# vector_c = [0.0, 0.0, 4.07825]*Angstrom
# lattice = UnitCell(vector_a, vector_b, vector_c)

# Define elements
elements_gold = ['Gold', 'Gold']

# Define coordinates
fractional_coordinates_gold = [[ 0.5,  0.5,  0.5],
                          [ 0. ,  0. ,  1. ]]

# # Set up configuration
# bulk_configuration_gold = BulkConfiguration(
#     bravais_lattice=lattice,
#     elements=elements,
#     fractional_coordinates=fractional_coordinates
#     )

# %%
# vector_a = [3.1604, 0.0, 0.0]*Angstrom
# vector_b = [0.0, 5.47397337224068, 0.0]*Angstrom
# vector_c = [0.0, 0.0, 12.295]*Angstrom
# lattice = UnitCell(vector_a, vector_b, vector_c)

# Define elements
elements_mos2 = ['Molybdenum', 'Sulfur', 'Sulfur', 'Molybdenum', 'Sulfur', 'Sulfur']

# Define coordinates
fractional_coordinates_mos2 = [[-0.            ,  0.666666666667,  0.25          ],
                          [-0.            ,  0.333333333333,  0.121         ],
                          [-0.            ,  0.333333333333,  0.379         ],
                          [ 0.5           ,  0.166666666667,  0.25          ],
                          [ 0.5           ,  0.833333333333,  0.121         ],
                          [ 0.5           ,  0.833333333333,  0.379         ]]

# Set up configuration
# bulk_configuration_mo = BulkConfiguration(
#     bravais_lattice=lattice,
#     elements=elements,
#     fractional_coordinates=fractional_coordinates
#     )

# %%
# from quantumatk import InterfaceBuilder, StrainSecond, nlsave

# # Setup interface builder
# interface_builder = InterfaceBuilder([bulk_configuration_gold, bulk_configuration_mo,bulk_configuration_gold2])

# # Get all of the interface matches, specifying that the second surface (MoS2) should be strained.
# matches = interface_builder.matches(strain_method=StrainSecond)

# # Print out table of matches
# interface_builder.nlprint()

# # print('{:>20s} {:>10s}'.format('number of atoms', 'strain (%)'))
# for match in matches:
#     # Get the number of atoms and strain from the match.
#     number_of_atoms = match.numberOfAtoms()
#     mean_absolute_strain = 100.0 * match.meanAbsoluteStrain()

#     # Print out information about the match.
#     print('{:20d} {:10.3f}'.format(number_of_atoms, mean_absolute_strain))

#     # Make the interface configuration and save it to a file.
#     interface_configuration = match.makeInterface()
#     nlsave('matches.hdf5', interface_configuration)

# # Scatter plot of number of atoms vs strain.
# import pylab
# pylab.scatter(
#     [100 * match.meanAbsoluteStrain() for match in matches],
#     [match.numberOfAtoms() for match in matches],
# )
# pylab.xlabel('Mean Absolute Strain (%)')
# pylab.ylabel('Number of Atoms')
# pylab.xscale('log')
# pylab.savefig('size_strain_plot.png')

# %%
# x depth (inside, outside)
# y up, down
# z left, right

# %%
# #GOLD x
# for i in range (1,49):
#     for i in range(1,49):
#         new_element = 'Gold' # Change Here

#         # Append the new element and coordinate to the lists
#         elements_gold.append(new_element)
#         fractional_coordinates_gold.append([coord + offset for coord, offset in zip(fractional_coordinates_gold[-1], [0.125, 0, 0])] )

#         if (i%8==0):
#             elements_gold.append(new_element)
#             fractional_coordinates_gold.append([coord + offset for coord, offset in zip(fractional_coordinates_gold[0], [0, 0, 0.062801])] )

#     if (i%8==0):
#             elements_gold.append(new_element)
#             fractional_coordinates_gold.append([coord + offset for coord, offset in zip(fractional_coordinates_gold[0], [0, -0.166666, 0])] )

# %%
# #GOLD x
# b=0

# for j in range (1,49):
#     for i in range(1,49):
#         new_element = 'Gold' # Change Here

#         if (i%8==0):
#             elements_gold.append(new_element)
#             # print(i)
#             fractional_coordinates_gold.append([coord + offset for coord, offset in zip(fractional_coordinates_gold[-8], [0, 0, 0.062801])] )
        
#         # Append the new element and coordinate to the lists
#         elements_gold.append(new_element)
#         fractional_coordinates_gold.append([coord + offset for coord, offset in zip(fractional_coordinates_gold[-1], [0.125, 0, 0])] )

        
#     if (j%8==0):
#             if(b==0):
#                 elements_gold.append(new_element)
#                 fractional_coordinates_gold.append([coord + offset for coord, offset in zip(fractional_coordinates_gold[-8], [0, -0.166666, 0])] )
#                 b=1
#             else:
#                 elements_gold.append(new_element)
#                 fractional_coordinates_gold.append([coord + offset for coord, offset in zip(fractional_coordinates_gold[-8], [0, -0.166666, 0])] )

# %%
# # Initialize the lists for storing elements and coordinates
# elements_gold = []
# fractional_coordinates_gold = []

# # Define the counts for each coordinate type
# x_count = 8  # Number of unique x coordinates
# y_count = 6  # Number of unique y coordinates
# z_count = 6  # Number of unique z coordinates

# # Generate unique coordinates
# for z_index in range(z_count):
#     for y_index in range(y_count):
#         for x_index in range(x_count):
#             new_element = 'Gold'
#             elements_gold.append(new_element)
#             x_coord = 0.5 + x_index * 0.125
#             y_coord = -1.16666 + y_index * 0.166666
#             z_coord = 0.562801 + z_index * 0.062801
#             fractional_coordinates_gold.append([x_coord, y_coord, z_coord])

# # Print the results to verify
# print("Total elements:", len(elements_gold))
# print("Total coordinates:", len(fractional_coordinates_gold))
# print("Sample coordinates:", fractional_coordinates_gold[:10])  # Print the first 10 coordinates to verify

# %%
# # Function to generate unique coordinates for elements
# def generate_gold_coordinates(x_count, y_count, z_count, x_start, y_start, z_start, x_step, y_step, z_step):
#     # elements_gold = []
#     # fractional_coordinates_gold = []

#     # Generate unique coordinates
#     for z_index in range(z_count):
#         for y_index in range(y_count):
#             for x_index in range(x_count):
#                 new_element = 'Gold'
#                 elements_gold.append(new_element)
#                 x_coord = x_start + x_index * x_step
#                 y_coord = y_start + y_index * y_step
#                 z_coord = z_start + z_index * z_step
#                 fractional_coordinates_gold.append([x_coord, y_coord, z_coord])

#     # Ensure exactly the required number of elements and coordinates
#     total_elements = x_count * y_count * z_count

#     return elements_gold, fractional_coordinates_gold

# # Parameters
# x_count = 8  # Number of unique x coordinates
# y_count = 6  # Number of unique y coordinates
# z_count = 6  # Number of unique z coordinates
# x_start = 0.5  # Starting x coordinate
# y_start = 0.5  # Starting y coordinate
# z_start = 0.5  # Starting z coordinate
# x_step = 0.125  # Step size for x coordinate
# y_step = 0.166666  # Step size for y coordinate
# z_step = 0.062801  # Step size for z coordinate

# # Generate coordinates
# elements_gold, fractional_coordinates_gold = generate_gold_coordinates(x_count, y_count, z_count, x_start, y_start, z_start, x_step, y_step, z_step)

# # Print the results to verify
# print("Total elements:", len(elements_gold))
# print("Total coordinates:", len(fractional_coordinates_gold))

# %%
elements_gold = []
fractional_coordinates_gold = []

# elements_gold = ['Gold', 'Gold']

# # Define coordinates
# fractional_coordinates_gold = [[ 0.5,  0.5,  0.5],
#                           [ 0. ,  0. ,  1. ]]

x_count = 8  # Number of unique x coordinates
y_count = 6  # Number of unique y coordinates
z_count = 8  # Number of unique z coordinates
x_start = 0.5  # Starting x coordinate
y_start = 0.5  # Starting y coordinate
z_start = 0.5  # Starting z coordinate
x_step = -0.5  # Step size for x coordinate
y_step = -0.5   # Step size for y coordinate
z_step = 0.5   # Step size for z coordinate
# x_step = 0.125  # Step size for x coordinate
# y_step = 0.166666  # Step size for y coordinate
# z_step = 0.062801  # Step size for z coordinate

for z_index in range(z_count):
    for y_index in range(y_count):
        for x_index in range(x_count):
            new_element = 'Gold'
            elements_gold.append(new_element)
            x_coord = x_start + x_index * x_step
            y_coord = y_start + y_index * y_step
            z_coord = z_start + z_index * z_step
            fractional_coordinates_gold.append([x_coord, y_coord, z_coord])

    # Ensure exactly the required number of elements and coordinates
    total_elements = x_count * y_count * z_count

print("Total elements:", len(elements_gold))
print("Total coordinates:", len(fractional_coordinates_gold))
# Out:
# Total elements: 384
# Total coordinates: 384

# %%
# #MoS2
# elements_mos2.append('Molybdenum',)
# elements_mos2.append('Sulfur',)
# elements_mos2.append('Sulfur',)
# # fractional_coordinates_mos2.append([coord + offset for coord, offset in zip(fractional_coordinates_mos2[-1], [[0, 0.25, 0.75], [0, 0.25, 0.75], [0, 0.25, 0.75]]  )] )
# fractional_coordinates_mos2.append([coord + offset for coord, offset in zip(fractional_coordinates_mos2[-3], [-0.166666, 0.125, 0])] )
# fractional_coordinates_mos2.append([coord + offset for coord, offset in zip(fractional_coordinates_mos2[-3], [0.166666, 0.125, 0.097695])] )
# fractional_coordinates_mos2.append([coord + offset for coord, offset in zip(fractional_coordinates_mos2[-3], [0.166666, 0.125, 0.097695])] )

# # Print the updated lists
# print("Updated elements:", elements_mos2)
# print("Updated fractional coordinates:", fractional_coordinates_mos2)

# %%
# #MoS2
# for i in range (1,49):
#     for i in range(1,49):
#         elements_mos2.append('Molybdenum',)
#         elements_mos2.append('Sulfur',)
#         elements_mos2.append('Sulfur',)

#         fractional_coordinates_mos2.append([coord + offset for coord, offset in zip(fractional_coordinates_mos2[-3], [-0.166666, 0, 0])] )
#         fractional_coordinates_mos2.append([coord + offset for coord, offset in zip(fractional_coordinates_mos2[-3], [0.166666, 0, 0])] )
#         fractional_coordinates_mos2.append([coord + offset for coord, offset in zip(fractional_coordinates_mos2[-3], [0.166666, 0, 0])] )

#         if (i%8==0):
#             fractional_coordinates_mos2.append([coord + offset for coord, offset in zip(fractional_coordinates_mos2[0], [-0.166666, 0.125, 0])] )
#             fractional_coordinates_mos2.append([coord + offset for coord, offset in zip(fractional_coordinates_mos2[1], [0.166666, 0.125, 0.097695])] )
#             fractional_coordinates_mos2.append([coord + offset for coord, offset in zip(fractional_coordinates_mos2[2], [0.166666, 0.125, 0.097695])] )

#     if (i%8==0):
#             fractional_coordinates_mos2.append([coord + offset for coord, offset in zip(fractional_coordinates_mos2[0], [-0.166666, 0.125, 0])] )
#             fractional_coordinates_mos2.append([coord + offset for coord, offset in zip(fractional_coordinates_mos2[1], [0.166666, 0.125, 0.097695])] )
#             fractional_coordinates_mos2.append([coord + offset for coord, offset in zip(fractional_coordinates_mos2[2], [0.166666, 0.125, 0.097695])] )

# %%
# Function to generate unique coordinates for an element
def generate_coordinates(x_count, y_count, z_count, x_start, y_start, z_start, x_step, y_step, z_step):
    elements_mos2 = []
    fractional_coordinates_mos2 = []

#     elements_mos2 = ['Molybdenum', 'Sulfur', 'Sulfur', 'Molybdenum', 'Sulfur', 'Sulfur']
# # Define coordinates
#     fractional_coordinates_mos2 = [[-0.            ,  0.666666666667,  0.25          ],
#                             [-0.            ,  0.333333333333,  0.121         ],
#                             [-0.            ,  0.333333333333,  0.379         ],
#                             [ 0.5           ,  0.166666666667,  0.25          ],
#                             [ 0.5           ,  0.833333333333,  0.121         ],
#                             [ 0.5           ,  0.833333333333,  0.379         ]]
    for z_index in range(z_count):
        for y_index in range(y_count):
            for x_index in range(x_count):
                elements_mos2.append('Element')  # Placeholder, will be replaced by the actual element
                x_coord = x_start + x_index * x_step
                y_coord = y_start + y_index * y_step
                z_coord = z_start + z_index * z_step
                fractional_coordinates_mos2.append([x_coord, y_coord, z_coord])
    return elements_mos2, fractional_coordinates_mos2

# Parameters for Molybdenum
x_count_mo = 6
y_count_mo = 8
z_count_mo = 1
x_start_mo = -0
y_start_mo = 0.666666666667
z_start_mo = 0.25
# x_start_mo = -0.166666
# y_start_mo = 0.125
# z_start_mo = 0.0
x_step_mo = 0.5
y_step_mo = 0.5
z_step_mo = 0
# x_step_mo = 0.333332
# y_step_mo = 0.125
# z_step_mo = 0.097695

# Parameters for Sulfur
x_count_s = 6
y_count_s = 8
z_count_s = 1
x_start_s = -0
y_start_s = 0.333333333333
z_start_s = 0.121 
# x_start_s = 0.166666
# y_start_s = 0.125
# z_start_s = 0.121 
x_step_s = 0.5
y_step_s = 0.5
z_step_s = 0
# x_step_s = 0.333332
# y_step_s = 0.125
# z_step_s = 0.097695

# Generate coordinates for Molybdenum
elements_mo, fractional_coordinates_mo = generate_coordinates(x_count_mo, y_count_mo, z_count_mo, x_start_mo, y_start_mo, z_start_mo, x_step_mo, y_step_mo, z_step_mo)
elements_mo = ['Molybdenum' for _ in elements_mo]  # Replace placeholder with actual element

# Generate coordinates for Sulfur
elements_s, fractional_coordinates_s = generate_coordinates(x_count_s, y_count_s, z_count_s, x_start_s, y_start_s, z_start_s, x_step_s, y_step_s, z_step_s)
elements_s = ['Sulfur' for _ in elements_s]  # Replace placeholder with actual element

# Combine elements and coordinates
elements_mos2 = elements_mo + elements_s + elements_s
fractional_coordinates_mos2 = fractional_coordinates_mo + fractional_coordinates_s + [[x, y, z - 0.258] for x, y, z in fractional_coordinates_s]

# Print the results to verify
print("Total elements:", len(elements_mos2))
print("Total coordinates:", len(fractional_coordinates_mos2))
# Out:
# Total elements: 144
# Total coordinates: 144

# %%
# gold, t 288
# x = 0.125
# y = -0.166666
# z = 0.062801
# s, 
# x = 0.166666
# y = 0.125
# z = 0.097695
# m 48, t 23
# x = -0.166666
# y = 0.125
# z = 0

# s,m
# 6,8 y
# 6,1 z
# 8,6 x

# %%
with open(f'exp.py', 'a') as file:
    file.write('''vector_a = [2.8837582303740374, 0.0, 0.0]*Angstrom
vector_b = [0.0, 2.8837582303740374, 0.0]*Angstrom
vector_c = [0.0, 0.0, 4.07825]*Angstrom
lattice = UnitCell(vector_a, vector_b, vector_c)\n\n''')

    # Write elements line by line
    file.write('elements = [\n')
    for element in elements_gold:
        file.write(f'"{element}",\n')
    file.write(']\n\n')

    # Write fractional coordinates line by line
    file.write('fractional_coordinates = [\n')
    for coord in fractional_coordinates_gold:
        file.write(f'    [{coord[0]}, {coord[1]}, {coord[2]}],\n')
    file.write(']\n\n')

    file.write("bulk_configuration_gold = BulkConfiguration(bravais_lattice=lattice,elements=elements,fractional_coordinates=fractional_coordinates)\n\n")

# %%
with open(f'exp.py', 'a') as file:
    file.write('''vector_a = [3.1604, 0.0, 0.0]*Angstrom
vector_b = [0.0, 5.47397337224068, 0.0]*Angstrom
vector_c = [0.0, 0.0, 12.295]*Angstrom
lattice = UnitCell(vector_a, vector_b, vector_c)\n\n''')

    # Write elements line by line
    file.write('elements = [\n')
    for element in elements_mos2:
        file.write(f'"{element}",\n')
    file.write(']\n\n')

    # Write fractional coordinates line by line
    file.write('fractional_coordinates = [\n')
    for coord in fractional_coordinates_mos2:
        file.write(f'    [{coord[0]}, {coord[1]}, {coord[2]}],\n')
    file.write(']\n\n')

    file.write("bulk_configuration_mo = BulkConfiguration(bravais_lattice=lattice,elements=elements,fractional_coordinates=fractional_coordinates)\n\n")

# %%
# with open(f'exp.py', 'a') as file:
#     file.write('''vector_a = [2.8837582303740374, 0.0, 0.0]*Angstrom
# vector_b = [0.0, 2.8837582303740374, 0.0]*Angstrom
# vector_c = [0.0, 0.0, 4.07825]*Angstrom
# lattice = UnitCell(vector_a, vector_b, vector_c)\n\n''')

#     # Write elements line by line
#     file.write('elements = [\n')
#     for element in elements_gold:
#         file.write(f'"{element}",\n')
#     file.write(']\n\n')

#     # Write fractional coordinates line by line
#     file.write('fractional_coordinates = [\n')
#     for coord in fractional_coordinates_gold:
#         file.write(f'    [{coord[0]}, {coord[1]}, {coord[2]}],\n')
#     file.write(']\n\n')

#     file.write("bulk_configuration_gold2 = BulkConfiguration(bravais_lattice=lattice,elements=elements,fractional_coordinates=fractional_coordinates)\n\n")

# %%
import os
# Function to remove single quotes from lines in a file
def remove_single_quotes_from_file(file_path):
    # Read lines from the input file
    with open(file_path, 'r') as f:
        lines = f.readlines()

    # Remove single quotes from each line
    cleaned_lines = [line.replace('"', "") for line in lines]

    # Write cleaned lines back to the same file
    with open(file_path, 'w') as f:
        f.writelines(cleaned_lines)

    print(f"Processed {file_path}. Double quotes removed.")

file_path = 'exp.py'

# Check if the file is a regular file (not a directory)
if os.path.isfile(file_path):
    # Remove single quotes from current file
    remove_single_quotes_from_file(file_path)
# Out:
# Processed exp.py. Double quotes removed.

# %%
with open(f'exp.py', 'a') as file:
    file.write('''interface_builder = InterfaceBuilder(bulk_configuration_gold, bulk_configuration_mo)

# Get all of the interface matches, specifying that the second surface (MoS2) should be strained.
matches = interface_builder.matches(strain_method=StrainBoth)

# Print out table of matches
interface_builder.nlprint()

# print('{:>20s} {:>10s}'.format('number of atoms', 'strain (%)'))
for match in matches:
    # Get the number of atoms and strain from the match.
    number_of_atoms = match.numberOfAtoms()
    mean_absolute_strain = 100.0 * match.meanAbsoluteStrain()

    # Print out information about the match.
    print('{:20d} {:10.3f}'.format(number_of_atoms, mean_absolute_strain))

    # Make the interface configuration and save it to a file.
    interface_configuration = match.makeInterface()
    nlsave('matches.hdf5', interface_configuration)

# Scatter plot of number of atoms vs strain.
import pylab
pylab.scatter(
    [100 * match.meanAbsoluteStrain() for match in matches],
    [match.numberOfAtoms() for match in matches],
)
pylab.xlabel('Mean Absolute Strain (%)')
pylab.ylabel('Number of Atoms')
pylab.xscale('log')
pylab.savefig('size_strain_plot.png')\n\n''')
